# %%
import os
import json

def create_solution_jsons(input_file_path, output_directory):
    """
    Create individual solution JSON files for each question in the input JSON.
    """
    try:
        # Read the input JSON file
        with open(input_file_path, 'r', encoding='utf-8') as file:
            data = json.load(file)
        
        # Extract the folder name from the file path
        # Get the parent directory of the json folder (e.g., 01_10021008481039611101693742355)
        folder_path = os.path.dirname(os.path.dirname(input_file_path))
        folder_name = os.path.basename(folder_path)
        
        # Extract the first part of the directory name (before the first '_')
        folder_prefix = folder_name.split('_')[0]  # Gets the first part before '_'
        
        # Define output folder
        output_folder = os.path.join(output_directory, folder_name)
        os.makedirs(output_folder, exist_ok=True)
        
        print(f"Processing folder: {folder_name}")
        print(f"Output directory: {output_folder}")
        
        # Loop through each question and create a new JSON for each
        for entry in data:
            question_number = entry.get('question_number')
            solution = [{
                "question_number": question_number,
                "solution_text": entry.get('solution_text'),
                "diagrams": entry.get('diagrams', []),
                "pages": entry.get('pages', [])
            }]
            
            # Define the solution file path with the new naming convention
            solution_file_path = os.path.join(output_folder, f"{folder_prefix}_solution_{question_number}.json")
            
            # Write the solution JSON to the file
            with open(solution_file_path, 'w', encoding='utf-8') as solution_file:
                json.dump(solution, solution_file, indent=2, ensure_ascii=False)
            
            print(f"  ✅ Solution {question_number} saved: {solution_file_path}")
    
    except Exception as e:
        print(f"❌ Error processing file {input_file_path}: {e}")

def process_output_directory(input_directory, output_directory):
    """
    Process all output_with_questions.json files in the specified directory structure.
    """
    processed_count = 0
    error_count = 0
    
    print(f"🔍 Scanning directory: {input_directory}")
    print(f"📂 Output will be saved to: {output_directory}")
    print("=" * 60)
    
    # Walk through all subdirectories
    for root, dirs, files in os.walk(input_directory):
        # Look for the specific file pattern: */json/output.json
        if 'output_with_questions.json' in files and root.endswith('json'):
            file_path = os.path.join(root, 'output_with_questions.json')
            print(f"📄 Found: {file_path}")
            
            try:
                create_solution_jsons(file_path, output_directory)
                processed_count += 1
            except Exception as e:
                print(f"❌ Error processing {file_path}: {e}")
                error_count += 1
    
    print("=" * 60)
    print(f"📊 PROCESSING SUMMARY:")
    print(f"✅ Successfully processed: {processed_count} files")
    print(f"❌ Errors encountered: {error_count} files")
    print("=" * 60)

def main():
    """
    Main function to run the solution creation process.
    """
    print("🎯 maths Solution JSON Creator")
    print("=" * 60)
    
    # Input directory containing the output folders
    input_directory = "/Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/output"
    
    # Output directory where solutions will be saved
    output_directory = "/Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions"
    
    # Verify input directory exists
    if not os.path.exists(input_directory):
        print(f"❌ Input directory does not exist: {input_directory}")
        return
    
    # Create output directory if it doesn't exist
    os.makedirs(output_directory, exist_ok=True)
    
    print(f"📂 Input directory:  {input_directory}")
    print(f"📂 Output directory: {output_directory}")
    
    # Process all files
    process_output_directory(input_directory, output_directory)

if __name__ == "__main__":
    main()
# Out:
# 🎯 maths Solution JSON Creator
# ============================================================
# 📂 Input directory:  /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/output
# 📂 Output directory: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions
# 🔍 Scanning directory: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/output
# 📂 Output will be saved to: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions
# ============================================================
# 📄 Found: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/output/12_1002140198994121111692513661/json/output_with_questions.json
# Processing folder: 12_1002140198994121111692513661
# Output directory: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/12_1002140198994121111692513661
#   ✅ Solution 1 saved: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/12_1002140198994121111692513661/12_solution_1.json
#   ✅ Solution 2 saved: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/12_1002140198994121111692513661/12_solution_2.json
#   ✅ Solution 3 saved: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/12_1002140198994121111692513661/12_solution_3.json
#   ✅ Solution 4 saved: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/12_1002140198994121111692513661/12_solution_4.json
# 📄 Found: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/output/09_1002114885961841111690700733/json/output_with_questions.json
# Processing folder: 09_1002114885961841111690700733
# Output directory: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/09_1002114885961841111690700733
#   ✅ Solution 1 saved: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/09_1002114885961841111690700733/09_solution_1.json
#   ✅ Solution 2 saved: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/09_1002114885961841111690700733/09_solution_2.json
#   ✅ Solution 3 saved: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/09_1002114885961841111690700733/09_solution_3.json
#   ✅ Solution 4 saved: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/09_1002114885961841111690700733/09_solution_4.json
# 📄 Found: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/output/10_10021138351083421111694954514/json/output_with_questions.json
# Processing folder: 10_10021138351083421111694954514
# Output directory: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/10_10021138351083421111694954514
#   ✅ Solution 1 saved: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/10_10021138351083421111694954514/10_solution_1.json
#   ✅ Solution 2 saved: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/10_10021138351083421111694954514/10_solution_2.json
#   ✅ Solution 3 saved: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/10_10021138351083421111694954514/10_solution_3.json
#   ✅ Solution 4 saved: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/10_10021138351083421111694954514/10_solution_4.json
#   ✅ Solution 5 saved: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/10_10021138351083421111694954514/10_solution_5.json
#   ✅ Solution 6 saved: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/10_10021138351083421111694954514/10_solution_6.json
#   ✅ Solution 7 saved: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/10_10021138351083421111694954514/10_solution_7.json
#   ✅ Solution 8 saved: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/10_10021138351083421111694954514/10_solution_8.json
#   ✅ Solution 9 saved: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/10_10021138351083421111694954514/10_solution_9.json
#   ✅ Solution 10 saved: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/10_10021138351083421111694954514/10_solution_10.json
#   ✅ Solution 11 saved: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/10_10021138351083421111694954514/10_solution_11.json
#   ✅ Solution 12 saved: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/10_10021138351083421111694954514/10_solution_12.json
# 📄 Found: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/output/02_1002137635994121111692517447/json/output_with_questions.json
# Processing folder: 02_1002137635994121111692517447
# Output directory: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/02_1002137635994121111692517447
#   ✅ Solution 1 saved: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/02_1002137635994121111692517447/02_solution_1.json
#   ✅ Solution 2 saved: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/02_1002137635994121111692517447/02_solution_2.json
#   ✅ Solution 3 saved: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/02_1002137635994121111692517447/02_solution_3.json
#   ✅ Solution 4 saved: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/02_1002137635994121111692517447/02_solution_4.json
# 📄 Found: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/output/13_10021000191039611111693742763/json/output_with_questions.json
# Processing folder: 13_10021000191039611111693742763
# Output directory: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/13_10021000191039611111693742763
#   ✅ Solution 1 saved: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/13_10021000191039611111693742763/13_solution_1.json
#   ✅ Solution 2 saved: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/13_10021000191039611111693742763/13_solution_2.json
#   ✅ Solution 3 saved: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/13_10021000191039611111693742763/13_solution_3.json
#   ✅ Solution 4 saved: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/13_10021000191039611111693742763/13_solution_4.json
#   ✅ Solution 5 saved: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/13_10021000191039611111693742763/13_solution_5.json
#   ✅ Solution 6 saved: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/13_10021000191039611111693742763/13_solution_6.json
#   ✅ Solution 7 saved: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/13_10021000191039611111693742763/13_solution_7.json
#   ✅ Solution 8 saved: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/13_10021000191039611111693742763/13_solution_8.json
#   ✅ Solution 9 saved: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/13_10021000191039611111693742763/13_solution_9.json
#   ✅ Solution 10 saved: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/13_10021000191039611111693742763/13_solution_10.json
#   ✅ Solution 11 saved: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/13_10021000191039611111693742763/13_solution_11.json
#   ✅ Solution 12 saved: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/13_10021000191039611111693742763/13_solution_12.json
# 📄 Found: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/output/11_100210067043036921111705241030/json/output_with_questions.json
# Processing folder: 11_100210067043036921111705241030
# Output directory: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/11_100210067043036921111705241030
#   ✅ Solution 1 saved: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/11_100210067043036921111705241030/11_solution_1.json
#   ✅ Solution 2 saved: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/11_100210067043036921111705241030/11_solution_2.json
#   ✅ Solution 3 saved: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/11_100210067043036921111705241030/11_solution_3.json
#   ✅ Solution 4 saved: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/11_100210067043036921111705241030/11_solution_4.json
#   ✅ Solution 5 saved: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/11_100210067043036921111705241030/11_solution_5.json
#   ✅ Solution 6 saved: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/11_100210067043036921111705241030/11_solution_6.json
# 📄 Found: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/output/01_10021040891039611111693747018/json/output_with_questions.json
# Processing folder: 01_10021040891039611111693747018
# Output directory: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/01_10021040891039611111693747018
#   ✅ Solution 1 saved: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/01_10021040891039611111693747018/01_solution_1.json
#   ✅ Solution 2 saved: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/01_10021040891039611111693747018/01_solution_2.json
#   ✅ Solution 3 saved: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/01_10021040891039611111693747018/01_solution_3.json
#   ✅ Solution 4 saved: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/01_10021040891039611111693747018/01_solution_4.json
#   ✅ Solution 5 saved: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/01_10021040891039611111693747018/01_solution_5.json
#   ✅ Solution 6 saved: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/01_10021040891039611111693747018/01_solution_6.json
#   ✅ Solution 7 saved: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/01_10021040891039611111693747018/01_solution_7.json
#   ✅ Solution 8 saved: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/01_10021040891039611111693747018/01_solution_8.json
#   ✅ Solution 9 saved: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/01_10021040891039611111693747018/01_solution_9.json
#   ✅ Solution 10 saved: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/01_10021040891039611111693747018/01_solution_10.json
#   ✅ Solution 11 saved: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/01_10021040891039611111693747018/01_solution_11.json
# 📄 Found: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/output/08_1002109149818371111684649303/json/output_with_questions.json
# Processing folder: 08_1002109149818371111684649303
# Output directory: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/08_1002109149818371111684649303
#   ✅ Solution 1 saved: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/08_1002109149818371111684649303/08_solution_1.json
#   ✅ Solution 3 saved: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/08_1002109149818371111684649303/08_solution_3.json
#   ✅ Solution 4 saved: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/08_1002109149818371111684649303/08_solution_4.json
# 📄 Found: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/output/05_1002110109818371111684651004/json/output_with_questions.json
# Processing folder: 05_1002110109818371111684651004
# Output directory: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/05_1002110109818371111684651004
#   ✅ Solution 1 saved: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/05_1002110109818371111684651004/05_solution_1.json
#   ✅ Solution 2 saved: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/05_1002110109818371111684651004/05_solution_2.json
#   ✅ Solution 3 saved: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/05_1002110109818371111684651004/05_solution_3.json
#   ✅ Solution 4 saved: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/05_1002110109818371111684651004/05_solution_4.json
# 📄 Found: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/output/04_100210408219741901111703509552/json/output_with_questions.json
# Processing folder: 04_100210408219741901111703509552
# Output directory: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/04_100210408219741901111703509552
#   ✅ Solution 1 saved: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/04_100210408219741901111703509552/04_solution_1.json
#   ✅ Solution 2 saved: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/04_100210408219741901111703509552/04_solution_2.json
#   ✅ Solution 3 saved: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/04_100210408219741901111703509552/04_solution_3.json
#   ✅ Solution 4 saved: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/04_100210408219741901111703509552/04_solution_4.json
#   ✅ Solution 5 saved: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/04_100210408219741901111703509552/04_solution_5.json
#   ✅ Solution 6 saved: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/04_100210408219741901111703509552/04_solution_6.json
# 📄 Found: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/output/03_10021054361083421111694958871/json/output_with_questions.json
# Processing folder: 03_10021054361083421111694958871
# Output directory: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/03_10021054361083421111694958871
#   ✅ Solution 1 saved: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/03_10021054361083421111694958871/03_solution_1.json
#   ✅ Solution 2 saved: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/03_10021054361083421111694958871/03_solution_2.json
#   ✅ Solution 3 saved: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/03_10021054361083421111694958871/03_solution_3.json
#   ✅ Solution 4 saved: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/03_10021054361083421111694958871/03_solution_4.json
#   ✅ Solution 5 saved: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/03_10021054361083421111694958871/03_solution_5.json
#   ✅ Solution 6 saved: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/03_10021054361083421111694958871/03_solution_6.json
#   ✅ Solution 7 saved: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/03_10021054361083421111694958871/03_solution_7.json
#   ✅ Solution 8 saved: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/03_10021054361083421111694958871/03_solution_8.json
#   ✅ Solution 9 saved: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/03_10021054361083421111694958871/03_solution_9.json
#   ✅ Solution 10 saved: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/03_10021054361083421111694958871/03_solution_10.json
#   ✅ Solution 11 saved: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/03_10021054361083421111694958871/03_solution_11.json
#   ✅ Solution 12 saved: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/03_10021054361083421111694958871/03_solution_12.json
# 📄 Found: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/output/14_1002108725961841111690697411/json/output_with_questions.json
# Processing folder: 14_1002108725961841111690697411
# Output directory: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/14_1002108725961841111690697411
#   ✅ Solution 1 saved: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/14_1002108725961841111690697411/14_solution_1.json
#   ✅ Solution 2 saved: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/14_1002108725961841111690697411/14_solution_2.json
#   ✅ Solution 3 saved: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/14_1002108725961841111690697411/14_solution_3.json
#   ✅ Solution 4 saved: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/14_1002108725961841111690697411/14_solution_4.json
# 📄 Found: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/output/06_100210285819741901111703513676/json/output_with_questions.json
# Processing folder: 06_100210285819741901111703513676
# Output directory: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/06_100210285819741901111703513676
#   ✅ Solution 1 saved: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/06_100210285819741901111703513676/06_solution_1.json
#   ✅ Solution 2 saved: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/06_100210285819741901111703513676/06_solution_2.json
#   ✅ Solution 3 saved: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/06_100210285819741901111703513676/06_solution_3.json
#   ✅ Solution 4 saved: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/06_100210285819741901111703513676/06_solution_4.json
#   ✅ Solution 5 saved: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/06_100210285819741901111703513676/06_solution_5.json
#   ✅ Solution 6 saved: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/06_100210285819741901111703513676/06_solution_6.json
# 📄 Found: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/output/07_100212788145098831111705212250/json/output_with_questions.json
# Processing folder: 07_100212788145098831111705212250
# Output directory: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/07_100212788145098831111705212250
#   ✅ Solution 1 saved: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/07_100212788145098831111705212250/07_solution_1.json
#   ✅ Solution 2 saved: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/07_100212788145098831111705212250/07_solution_2.json
#   ✅ Solution 3 saved: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/07_100212788145098831111705212250/07_solution_3.json
#   ✅ Solution 4 saved: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/07_100212788145098831111705212250/07_solution_4.json
#   ✅ Solution 5 saved: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/07_100212788145098831111705212250/07_solution_5.json
#   ✅ Solution 6 saved: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/07_100212788145098831111705212250/07_solution_6.json
#   ✅ Solution 7 saved: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/07_100212788145098831111705212250/07_solution_7.json
#   ✅ Solution 8 saved: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/07_100212788145098831111705212250/07_solution_8.json
#   ✅ Solution 9 saved: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/07_100212788145098831111705212250/07_solution_9.json
#   ✅ Solution 10 saved: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/07_100212788145098831111705212250/07_solution_10.json
#   ✅ Solution 11 saved: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/07_100212788145098831111705212250/07_solution_11.json
#   ✅ Solution 12 saved: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/07_100212788145098831111705212250/07_solution_12.json
# 📄 Found: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/output/15_10021105101083421111694960631/json/output_with_questions.json
# Processing folder: 15_10021105101083421111694960631
# Output directory: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/15_10021105101083421111694960631
#   ✅ Solution 1 saved: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/15_10021105101083421111694960631/15_solution_1.json
#   ✅ Solution 2 saved: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/15_10021105101083421111694960631/15_solution_2.json
#   ✅ Solution 3 saved: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/15_10021105101083421111694960631/15_solution_3.json
#   ✅ Solution 4 saved: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/15_10021105101083421111694960631/15_solution_4.json
#   ✅ Solution 5 saved: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/15_10021105101083421111694960631/15_solution_5.json
#   ✅ Solution 6 saved: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/15_10021105101083421111694960631/15_solution_6.json
#   ✅ Solution 7 saved: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/15_10021105101083421111694960631/15_solution_7.json
#   ✅ Solution 8 saved: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/15_10021105101083421111694960631/15_solution_8.json
#   ✅ Solution 9 saved: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/15_10021105101083421111694960631/15_solution_9.json
#   ✅ Solution 10 saved: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/15_10021105101083421111694960631/15_solution_10.json
#   ✅ Solution 11 saved: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/15_10021105101083421111694960631/15_solution_11.json
#   ✅ Solution 12 saved: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions/15_10021105101083421111694960631/15_solution_12.json
# ============================================================
# 📊 PROCESSING SUMMARY:
# ✅ Successfully processed: 15 files
# ❌ Errors encountered: 0 files
# ============================================================

# %% [markdown]
# ## to make table

# %%
import os
import json

class OCRComparator:
    def __init__(self, gemini_dir, output_dir):
        """
        Initialize with just 2 base directories
        """
        self.gemini_dir = gemini_dir  
        self.output_dir = output_dir
        
        print(f"🤖 Gemini OCR directory: {self.gemini_dir}")
        print(f"💾 Output directory:     {self.output_dir}")
        print("=" * 70)
    
    def compare_solution_files(self, solution_folder, solution_number, file_prefix):
        """
        Process a single solution file from Gemini OCR
        """
        # Build file paths using the base directories
        gemini_file = os.path.join(
            self.gemini_dir, solution_folder, f"{file_prefix}_solution_{solution_number}.json"
        )
        
        output_file = os.path.join(
            self.output_dir, solution_folder, f"{file_prefix}_solution_{solution_number}_table.json"
        )
        
        print(f"🔄 Processing solution {solution_number} in {solution_folder}")
        
        # Initialize combined data structure
        combined_data = {
            "question_number": solution_number,
            "ocr_text": "NA",
            "ocr_pages": [],
            "pdf_name": solution_folder
        }
        
        # Read Gemini OCR data
        if os.path.exists(gemini_file):
            try:
                with open(gemini_file, 'r', encoding='utf-8') as f:
                    gemini_data = json.load(f)
                    
                if isinstance(gemini_data, list) and len(gemini_data) > 0:
                    gemini_item = gemini_data[0]
                    combined_data["ocr_text"] = gemini_item.get('solution_text', 'NA')
                    combined_data["ocr_pages"] = gemini_item.get('pages', [])
                    combined_data["question_number"] = gemini_item.get('question_number', solution_number)
                    print(f"   ✅ Gemini text loaded: {len(str(combined_data['ocr_text']))} chars")
                    print(f"   📄 Pages: {combined_data['ocr_pages']}")
                else:
                    print(f"   ⚠️  Gemini file format issue: {gemini_file}")
                    
            except Exception as e:
                print(f"   ❌ Error reading Gemini file: {e}")
        else:
            print(f"   ❌ Gemini file not found: {gemini_file}")
        
        # Save combined data
        os.makedirs(os.path.dirname(output_file), exist_ok=True)
        
        try:
            with open(output_file, 'w', encoding='utf-8') as f:
                json.dump(combined_data, f, indent=2, ensure_ascii=False)
            print(f"   💾 Saved: {os.path.basename(output_file)}")
            return True
        except Exception as e:
            print(f"   ❌ Error saving output: {e}")
            return False
    
    def process_all_solutions(self):
        """
        Process all solution folders and files
        """
        if not os.path.exists(self.gemini_dir):
            print(f"❌ Gemini directory not found: {self.gemini_dir}")
            return
            
        total_processed = 0
        successful = 0
        errors = 0
        
        print(f"🔍 Scanning Gemini directory: {self.gemini_dir}")
        
        # Iterate through all solution folders
        for solution_folder in os.listdir(self.gemini_dir):
            solution_folder_path = os.path.join(self.gemini_dir, solution_folder)
            
            if not os.path.isdir(solution_folder_path):
                continue
                
            print(f"\n📂 Processing folder: {solution_folder}")
            
            # Process all JSON files in this folder
            for filename in os.listdir(solution_folder_path):
                if filename.endswith('.json') and '_solution_' in filename:
                    try:
                        # Parse filename to extract prefix and solution number
                        file_prefix = filename.split('_solution_')[0]
                        solution_number = int(filename.split('_solution_')[1].split('.')[0])
                        
                        total_processed += 1
                        
                        # Process this solution file
                        success = self.compare_solution_files(solution_folder, solution_number, file_prefix)
                        
                        if success:
                            successful += 1
                        else:
                            errors += 1
                            
                    except Exception as e:
                        print(f"   ❌ Filename parse error for {filename}: {e}")
                        errors += 1
                        total_processed += 1
        
        # Print summary
        print("\n" + "=" * 70)
        print("📊 PROCESSING SUMMARY")
        print("=" * 70)
        print(f"Total files processed: {total_processed}")
        print(f"Successfully processed: {successful}")
        print(f"Errors encountered:    {errors}")
        print(f"Success rate:          {(successful/total_processed)*100:.1f}%" if total_processed > 0 else "N/A")
        print("=" * 70)

def main():
    """
    Main function - define your 2 directories here
    """
    print("🔧 OCR Processing Tool")
    print("=" * 70)
    
    # ===== DEFINE YOUR 2 DIRECTORIES HERE =====
    base_path = "/Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb"
    
    gemini_ocr_dir = os.path.join(base_path, "Physics/Physics_Gemini/solutions") 
    output_dir = os.path.join(base_path, "Physics/table")
    
    # ===== END DIRECTORY DEFINITIONS =====
    
    # Create comparator and run
    comparator = OCRComparator(gemini_ocr_dir, output_dir)
    comparator.process_all_solutions()
    
    print("\n✅ OCR processing complete!")

if __name__ == "__main__":
    main()
# Out:
# 🔧 OCR Processing Tool
# ======================================================================
# 🤖 Gemini OCR directory: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions
# 💾 Output directory:     /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/table
# ======================================================================
# 🔍 Scanning Gemini directory: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/Physics_Gemini/solutions
#
# 📂 Processing folder: 12_1002140198994121111692513661
# 🔄 Processing solution 1 in 12_1002140198994121111692513661
#    ✅ Gemini text loaded: 14 chars
#    📄 Pages: [1]
#    💾 Saved: 12_solution_1_table.json
# 🔄 Processing solution 2 in 12_1002140198994121111692513661
#    ✅ Gemini text loaded: 109 chars
#    📄 Pages: [1]
#    💾 Saved: 12_solution_2_table.json
# 🔄 Processing solution 3 in 12_1002140198994121111692513661
#    ✅ Gemini text loaded: 361 chars
#    📄 Pages: [1]
#    💾 Saved: 12_solution_3_table.json
# 🔄 Processing solution 4 in 12_1002140198994121111692513661
#    ✅ Gemini text loaded: 285 chars
#    📄 Pages: [2]
#    💾 Saved: 12_solution_4_table.json
#
# 📂 Processing folder: 09_1002114885961841111690700733
# 🔄 Processing solution 4 in 09_1002114885961841111690700733
#    ✅ Gemini text loaded: 471 chars
#    📄 Pages: [2, 3]
#    💾 Saved: 09_solution_4_table.json
# 🔄 Processing solution 2 in 09_1002114885961841111690700733
#    ✅ Gemini text loaded: 57 chars
#    📄 Pages: [1]
#    💾 Saved: 09_solution_2_table.json
# 🔄 Processing solution 3 in 09_1002114885961841111690700733
#    ✅ Gemini text loaded: 213 chars
#    📄 Pages: [1]
#    💾 Saved: 09_solution_3_table.json
# 🔄 Processing solution 1 in 09_1002114885961841111690700733
#    ✅ Gemini text loaded: 18 chars
#    📄 Pages: [1]
#    💾 Saved: 09_solution_1_table.json
#
# 📂 Processing folder: 10_10021138351083421111694954514
# 🔄 Processing solution 4 in 10_10021138351083421111694954514
#    ✅ Gemini text loaded: 66 chars
#    📄 Pages: [1]
#    💾 Saved: 10_solution_4_table.json
# 🔄 Processing solution 10 in 10_10021138351083421111694954514
#    ✅ Gemini text loaded: 166 chars
#    📄 Pages: [5]
#    💾 Saved: 10_solution_10_table.json
# 🔄 Processing solution 8 in 10_10021138351083421111694954514
#    ✅ Gemini text loaded: 258 chars
#    📄 Pages: [3]
#    💾 Saved: 10_solution_8_table.json
# 🔄 Processing solution 9 in 10_10021138351083421111694954514
#    ✅ Gemini text loaded: 146 chars
#    📄 Pages: [3, 4]
#    💾 Saved: 10_solution_9_table.json
# 🔄 Processing solution 11 in 10_10021138351083421111694954514
#    ✅ Gemini text loaded: 249 chars
#    📄 Pages: [5, 6]
#    💾 Saved: 10_solution_11_table.json
# 🔄 Processing solution 5 in 10_10021138351083421111694954514
#    ✅ Gemini text loaded: 96 chars
#    📄 Pages: [1]
#    💾 Saved: 10_solution_5_table.json
# 🔄 Processing solution 2 in 10_10021138351083421111694954514
#    ✅ Gemini text loaded: 34 chars
#    📄 Pages: [1]
#    💾 Saved: 10_solution_2_table.json
# 🔄 Processing solution 3 in 10_10021138351083421111694954514
#    ✅ Gemini text loaded: 33 chars
#    📄 Pages: [1]
#    💾 Saved: 10_solution_3_table.json
# 🔄 Processing solution 1 in 10_10021138351083421111694954514
#    ✅ Gemini text loaded: 10 chars
#    📄 Pages: [1]
#    💾 Saved: 10_solution_1_table.json
# 🔄 Processing solution 6 in 10_10021138351083421111694954514
#    ✅ Gemini text loaded: 170 chars
#    📄 Pages: [1]
#    💾 Saved: 10_solution_6_table.json
# 🔄 Processing solution 12 in 10_10021138351083421111694954514
#    ✅ Gemini text loaded: 618 chars
#    📄 Pages: [6, 7]
#    💾 Saved: 10_solution_12_table.json
# 🔄 Processing solution 7 in 10_10021138351083421111694954514
#    ✅ Gemini text loaded: 443 chars
#    📄 Pages: [1, 2]
#    💾 Saved: 10_solution_7_table.json
#
# 📂 Processing folder: 02_1002137635994121111692517447
# 🔄 Processing solution 1 in 02_1002137635994121111692517447
#    ✅ Gemini text loaded: 14 chars
#    📄 Pages: [2]
#    💾 Saved: 02_solution_1_table.json
# 🔄 Processing solution 4 in 02_1002137635994121111692517447
#    ✅ Gemini text loaded: 331 chars
#    📄 Pages: [1, 2]
#    💾 Saved: 02_solution_4_table.json
# 🔄 Processing solution 2 in 02_1002137635994121111692517447
#    ✅ Gemini text loaded: 8 chars
#    📄 Pages: [2]
#    💾 Saved: 02_solution_2_table.json
# 🔄 Processing solution 3 in 02_1002137635994121111692517447
#    ✅ Gemini text loaded: 141 chars
#    📄 Pages: [2]
#    💾 Saved: 02_solution_3_table.json
#
# 📂 Processing folder: 13_10021000191039611111693742763
# 🔄 Processing solution 1 in 13_10021000191039611111693742763
#    ✅ Gemini text loaded: 14 chars
#    📄 Pages: [1]
#    💾 Saved: 13_solution_1_table.json
# 🔄 Processing solution 12 in 13_10021000191039611111693742763
#    ✅ Gemini text loaded: 312 chars
#    📄 Pages: [4]
#    💾 Saved: 13_solution_12_table.json
# 🔄 Processing solution 7 in 13_10021000191039611111693742763
#    ✅ Gemini text loaded: 318 chars
#    📄 Pages: [1]
#    💾 Saved: 13_solution_7_table.json
# 🔄 Processing solution 6 in 13_10021000191039611111693742763
#    ✅ Gemini text loaded: 86 chars
#    📄 Pages: [1]
#    💾 Saved: 13_solution_6_table.json
# 🔄 Processing solution 9 in 13_10021000191039611111693742763
#    ✅ Gemini text loaded: 155 chars
#    📄 Pages: [3]
#    💾 Saved: 13_solution_9_table.json
# 🔄 Processing solution 5 in 13_10021000191039611111693742763
#    ✅ Gemini text loaded: 138 chars
#    📄 Pages: [1]
#    💾 Saved: 13_solution_5_table.json
# 🔄 Processing solution 4 in 13_10021000191039611111693742763
#    ✅ Gemini text loaded: 26 chars
#    📄 Pages: [1]
#    💾 Saved: 13_solution_4_table.json
# 🔄 Processing solution 8 in 13_10021000191039611111693742763
#    ✅ Gemini text loaded: 433 chars
#    📄 Pages: [2]
#    💾 Saved: 13_solution_8_table.json
# 🔄 Processing solution 10 in 13_10021000191039611111693742763
#    ✅ Gemini text loaded: 388 chars
#    📄 Pages: [3]
#    💾 Saved: 13_solution_10_table.json
# 🔄 Processing solution 3 in 13_10021000191039611111693742763
#    ✅ Gemini text loaded: 21 chars
#    📄 Pages: [1]
#    💾 Saved: 13_solution_3_table.json
# 🔄 Processing solution 2 in 13_10021000191039611111693742763
#    ✅ Gemini text loaded: 12 chars
#    📄 Pages: [1]
#    💾 Saved: 13_solution_2_table.json
# 🔄 Processing solution 11 in 13_10021000191039611111693742763
#    ✅ Gemini text loaded: 211 chars
#    📄 Pages: [3, 4]
#    💾 Saved: 13_solution_11_table.json
#
# 📂 Processing folder: 11_100210067043036921111705241030
# 🔄 Processing solution 3 in 11_100210067043036921111705241030
#    ✅ Gemini text loaded: 20 chars
#    📄 Pages: [1]
#    💾 Saved: 11_solution_3_table.json
# 🔄 Processing solution 2 in 11_100210067043036921111705241030
#    ✅ Gemini text loaded: 9 chars
#    📄 Pages: [1]
#    💾 Saved: 11_solution_2_table.json
# 🔄 Processing solution 5 in 11_100210067043036921111705241030
#    ✅ Gemini text loaded: 877 chars
#    📄 Pages: [2, 3]
#    💾 Saved: 11_solution_5_table.json
# 🔄 Processing solution 4 in 11_100210067043036921111705241030
#    ✅ Gemini text loaded: 242 chars
#    📄 Pages: [1, 2]
#    💾 Saved: 11_solution_4_table.json
# 🔄 Processing solution 6 in 11_100210067043036921111705241030
#    ✅ Gemini text loaded: 754 chars
#    📄 Pages: [3, 4]
#    💾 Saved: 11_solution_6_table.json
# 🔄 Processing solution 1 in 11_100210067043036921111705241030
#    ✅ Gemini text loaded: 8 chars
#    📄 Pages: [1]
#    💾 Saved: 11_solution_1_table.json
#
# 📂 Processing folder: 01_10021040891039611111693747018
# 🔄 Processing solution 9 in 01_10021040891039611111693747018
#    ✅ Gemini text loaded: 185 chars
#    📄 Pages: [3]
#    💾 Saved: 01_solution_9_table.json
# 🔄 Processing solution 5 in 01_10021040891039611111693747018
#    ✅ Gemini text loaded: 125 chars
#    📄 Pages: [1]
#    💾 Saved: 01_solution_5_table.json
# 🔄 Processing solution 4 in 01_10021040891039611111693747018
#    ✅ Gemini text loaded: 40 chars
#    📄 Pages: [1]
#    💾 Saved: 01_solution_4_table.json
# 🔄 Processing solution 8 in 01_10021040891039611111693747018
#    ✅ Gemini text loaded: 235 chars
#    📄 Pages: [2, 3]
#    💾 Saved: 01_solution_8_table.json
# 🔄 Processing solution 11 in 01_10021040891039611111693747018
#    ✅ Gemini text loaded: 643 chars
#    📄 Pages: [5]
#    💾 Saved: 01_solution_11_table.json
# 🔄 Processing solution 3 in 01_10021040891039611111693747018
#    ✅ Gemini text loaded: 20 chars
#    📄 Pages: [1]
#    💾 Saved: 01_solution_3_table.json
# 🔄 Processing solution 2 in 01_10021040891039611111693747018
#    ✅ Gemini text loaded: 12 chars
#    📄 Pages: [1]
#    💾 Saved: 01_solution_2_table.json
# 🔄 Processing solution 10 in 01_10021040891039611111693747018
#    ✅ Gemini text loaded: 1150 chars
#    📄 Pages: [3, 4]
#    💾 Saved: 01_solution_10_table.json
# 🔄 Processing solution 1 in 01_10021040891039611111693747018
#    ✅ Gemini text loaded: 16 chars
#    📄 Pages: [1]
#    💾 Saved: 01_solution_1_table.json
# 🔄 Processing solution 7 in 01_10021040891039611111693747018
#    ✅ Gemini text loaded: 140 chars
#    📄 Pages: [2]
#    💾 Saved: 01_solution_7_table.json
# 🔄 Processing solution 6 in 01_10021040891039611111693747018
#    ✅ Gemini text loaded: 170 chars
#    📄 Pages: [1]
#    💾 Saved: 01_solution_6_table.json
#
# 📂 Processing folder: 08_1002109149818371111684649303
# 🔄 Processing solution 3 in 08_1002109149818371111684649303
#    ✅ Gemini text loaded: 102 chars
#    📄 Pages: [1]
#    💾 Saved: 08_solution_3_table.json
# 🔄 Processing solution 4 in 08_1002109149818371111684649303
#    ✅ Gemini text loaded: 317 chars
#    📄 Pages: [2]
#    💾 Saved: 08_solution_4_table.json
# 🔄 Processing solution 1 in 08_1002109149818371111684649303
#    ✅ Gemini text loaded: 46 chars
#    📄 Pages: [1]
#    💾 Saved: 08_solution_1_table.json
#
# 📂 Processing folder: 05_1002110109818371111684651004
# 🔄 Processing solution 1 in 05_1002110109818371111684651004
#    ✅ Gemini text loaded: 25 chars
#    📄 Pages: [1]
#    💾 Saved: 05_solution_1_table.json
# 🔄 Processing solution 4 in 05_1002110109818371111684651004
#    ✅ Gemini text loaded: 272 chars
#    📄 Pages: [2]
#    💾 Saved: 05_solution_4_table.json
# 🔄 Processing solution 3 in 05_1002110109818371111684651004
#    ✅ Gemini text loaded: 132 chars
#    📄 Pages: [1]
#    💾 Saved: 05_solution_3_table.json
# 🔄 Processing solution 2 in 05_1002110109818371111684651004
#    ✅ Gemini text loaded: 123 chars
#    📄 Pages: [1]
#    💾 Saved: 05_solution_2_table.json
#
# 📂 Processing folder: 04_100210408219741901111703509552
# 🔄 Processing solution 6 in 04_100210408219741901111703509552
#    ✅ Gemini text loaded: 839 chars
#    📄 Pages: [2, 3, 4]
#    💾 Saved: 04_solution_6_table.json
# 🔄 Processing solution 1 in 04_100210408219741901111703509552
#    ✅ Gemini text loaded: 24 chars
#    📄 Pages: [1]
#    💾 Saved: 04_solution_1_table.json
# 🔄 Processing solution 2 in 04_100210408219741901111703509552
#    ✅ Gemini text loaded: 151 chars
#    📄 Pages: [1]
#    💾 Saved: 04_solution_2_table.json
# 🔄 Processing solution 3 in 04_100210408219741901111703509552
#    ✅ Gemini text loaded: 22 chars
#    📄 Pages: [1]
#    💾 Saved: 04_solution_3_table.json
# 🔄 Processing solution 4 in 04_100210408219741901111703509552
#    ✅ Gemini text loaded: 384 chars
#    📄 Pages: [1]
#    💾 Saved: 04_solution_4_table.json
# 🔄 Processing solution 5 in 04_100210408219741901111703509552
#    ✅ Gemini text loaded: 205 chars
#    📄 Pages: [2]
#    💾 Saved: 04_solution_5_table.json
#
# 📂 Processing folder: 03_10021054361083421111694958871
# 🔄 Processing solution 7 in 03_10021054361083421111694958871
#    ✅ Gemini text loaded: 298 chars
#    📄 Pages: [1, 2]
#    💾 Saved: 03_solution_7_table.json
# 🔄 Processing solution 6 in 03_10021054361083421111694958871
#    ✅ Gemini text loaded: 174 chars
#    📄 Pages: [1]
#    💾 Saved: 03_solution_6_table.json
# 🔄 Processing solution 12 in 03_10021054361083421111694958871
#    ✅ Gemini text loaded: 510 chars
#    📄 Pages: [4, 5]
#    💾 Saved: 03_solution_12_table.json
# 🔄 Processing solution 1 in 03_10021054361083421111694958871
#    ✅ Gemini text loaded: 11 chars
#    📄 Pages: [1]
#    💾 Saved: 03_solution_1_table.json
# 🔄 Processing solution 3 in 03_10021054361083421111694958871
#    ✅ Gemini text loaded: 34 chars
#    📄 Pages: [1]
#    💾 Saved: 03_solution_3_table.json
# 🔄 Processing solution 2 in 03_10021054361083421111694958871
#    ✅ Gemini text loaded: 34 chars
#    📄 Pages: [1]
#    💾 Saved: 03_solution_2_table.json
# 🔄 Processing solution 9 in 03_10021054361083421111694958871
#    ✅ Gemini text loaded: 232 chars
#    📄 Pages: [2, 3]
#    💾 Saved: 03_solution_9_table.json
# 🔄 Processing solution 5 in 03_10021054361083421111694958871
#    ✅ Gemini text loaded: 44 chars
#    📄 Pages: [1]
#    💾 Saved: 03_solution_5_table.json
# 🔄 Processing solution 11 in 03_10021054361083421111694958871
#    ✅ Gemini text loaded: 272 chars
#    📄 Pages: [3, 4]
#    💾 Saved: 03_solution_11_table.json
# 🔄 Processing solution 10 in 03_10021054361083421111694958871
#    ✅ Gemini text loaded: 190 chars
#    📄 Pages: [3]
#    💾 Saved: 03_solution_10_table.json
# 🔄 Processing solution 4 in 03_10021054361083421111694958871
#    ✅ Gemini text loaded: 58 chars
#    📄 Pages: [1]
#    💾 Saved: 03_solution_4_table.json
# 🔄 Processing solution 8 in 03_10021054361083421111694958871
#    ✅ Gemini text loaded: 209 chars
#    📄 Pages: [2]
#    💾 Saved: 03_solution_8_table.json
#
# 📂 Processing folder: 14_1002108725961841111690697411
# 🔄 Processing solution 1 in 14_1002108725961841111690697411
#    ✅ Gemini text loaded: 49 chars
#    📄 Pages: [1]
#    💾 Saved: 14_solution_1_table.json
# 🔄 Processing solution 4 in 14_1002108725961841111690697411
#    ✅ Gemini text loaded: 206 chars
#    📄 Pages: [3, 4]
#    💾 Saved: 14_solution_4_table.json
# 🔄 Processing solution 2 in 14_1002108725961841111690697411
#    ✅ Gemini text loaded: 135 chars
#    📄 Pages: [1]
#    💾 Saved: 14_solution_2_table.json
# 🔄 Processing solution 3 in 14_1002108725961841111690697411
#    ✅ Gemini text loaded: 138 chars
#    📄 Pages: [2]
#    💾 Saved: 14_solution_3_table.json
#
# 📂 Processing folder: 06_100210285819741901111703513676
# 🔄 Processing solution 4 in 06_100210285819741901111703513676
#    ✅ Gemini text loaded: 363 chars
#    📄 Pages: [1, 2]
#    💾 Saved: 06_solution_4_table.json
# 🔄 Processing solution 5 in 06_100210285819741901111703513676
#    ✅ Gemini text loaded: 237 chars
#    📄 Pages: [2, 3]
#    💾 Saved: 06_solution_5_table.json
# 🔄 Processing solution 2 in 06_100210285819741901111703513676
#    ✅ Gemini text loaded: 120 chars
#    📄 Pages: [1]
#    💾 Saved: 06_solution_2_table.json
# 🔄 Processing solution 3 in 06_100210285819741901111703513676
#    ✅ Gemini text loaded: 20 chars
#    📄 Pages: [1]
#    💾 Saved: 06_solution_3_table.json
# 🔄 Processing solution 1 in 06_100210285819741901111703513676
#    ✅ Gemini text loaded: 21 chars
#    📄 Pages: [1]
#    💾 Saved: 06_solution_1_table.json
# 🔄 Processing solution 6 in 06_100210285819741901111703513676
#    ✅ Gemini text loaded: 939 chars
#    📄 Pages: [3, 4, 5, 6]
#    💾 Saved: 06_solution_6_table.json
#
# 📂 Processing folder: 07_100212788145098831111705212250
# 🔄 Processing solution 12 in 07_100212788145098831111705212250
#    ✅ Gemini text loaded: 303 chars
#    📄 Pages: [6]
#    💾 Saved: 07_solution_12_table.json
# 🔄 Processing solution 3 in 07_100212788145098831111705212250
#    ✅ Gemini text loaded: 8 chars
#    📄 Pages: [1]
#    💾 Saved: 07_solution_3_table.json
# 🔄 Processing solution 2 in 07_100212788145098831111705212250
#    ✅ Gemini text loaded: 8 chars
#    📄 Pages: [1]
#    💾 Saved: 07_solution_2_table.json
# 🔄 Processing solution 5 in 07_100212788145098831111705212250
#    ✅ Gemini text loaded: 8 chars
#    📄 Pages: [1]
#    💾 Saved: 07_solution_5_table.json
# 🔄 Processing solution 9 in 07_100212788145098831111705212250
#    ✅ Gemini text loaded: 216 chars
#    📄 Pages: [3]
#    💾 Saved: 07_solution_9_table.json
# 🔄 Processing solution 8 in 07_100212788145098831111705212250
#    ✅ Gemini text loaded: 261 chars
#    📄 Pages: [2, 3]
#    💾 Saved: 07_solution_8_table.json
# 🔄 Processing solution 4 in 07_100212788145098831111705212250
#    ✅ Gemini text loaded: 8 chars
#    📄 Pages: [1]
#    💾 Saved: 07_solution_4_table.json
# 🔄 Processing solution 7 in 07_100212788145098831111705212250
#    ✅ Gemini text loaded: 338 chars
#    📄 Pages: [1, 2]
#    💾 Saved: 07_solution_7_table.json
# 🔄 Processing solution 6 in 07_100212788145098831111705212250
#    ✅ Gemini text loaded: 143 chars
#    📄 Pages: [1]
#    💾 Saved: 07_solution_6_table.json
# 🔄 Processing solution 1 in 07_100212788145098831111705212250
#    ✅ Gemini text loaded: 8 chars
#    📄 Pages: [1]
#    💾 Saved: 07_solution_1_table.json
# 🔄 Processing solution 10 in 07_100212788145098831111705212250
#    ✅ Gemini text loaded: 366 chars
#    📄 Pages: [3, 4]
#    💾 Saved: 07_solution_10_table.json
# 🔄 Processing solution 11 in 07_100212788145098831111705212250
#    ✅ Gemini text loaded: 718 chars
#    📄 Pages: [4, 5]
#    💾 Saved: 07_solution_11_table.json
#
# 📂 Processing folder: 15_10021105101083421111694960631
# 🔄 Processing solution 7 in 15_10021105101083421111694960631
#    ✅ Gemini text loaded: 367 chars
#    📄 Pages: [1, 2]
#    💾 Saved: 15_solution_7_table.json
# 🔄 Processing solution 6 in 15_10021105101083421111694960631
#    ✅ Gemini text loaded: 333 chars
#    📄 Pages: [1]
#    💾 Saved: 15_solution_6_table.json
# 🔄 Processing solution 11 in 15_10021105101083421111694960631
#    ✅ Gemini text loaded: 331 chars
#    📄 Pages: [4, 5]
#    💾 Saved: 15_solution_11_table.json
# 🔄 Processing solution 1 in 15_10021105101083421111694960631
#    ✅ Gemini text loaded: 11 chars
#    📄 Pages: [1]
#    💾 Saved: 15_solution_1_table.json
# 🔄 Processing solution 10 in 15_10021105101083421111694960631
#    ✅ Gemini text loaded: 196 chars
#    📄 Pages: [4]
#    💾 Saved: 15_solution_10_table.json
# 🔄 Processing solution 3 in 15_10021105101083421111694960631
#    ✅ Gemini text loaded: 33 chars
#    📄 Pages: [1]
#    💾 Saved: 15_solution_3_table.json
# 🔄 Processing solution 12 in 15_10021105101083421111694960631
#    ✅ Gemini text loaded: 982 chars
#    📄 Pages: [5, 6]
#    💾 Saved: 15_solution_12_table.json
# 🔄 Processing solution 2 in 15_10021105101083421111694960631
#    ✅ Gemini text loaded: 31 chars
#    📄 Pages: [1]
#    💾 Saved: 15_solution_2_table.json
# 🔄 Processing solution 5 in 15_10021105101083421111694960631
#    ✅ Gemini text loaded: 45 chars
#    📄 Pages: [1]
#    💾 Saved: 15_solution_5_table.json
# 🔄 Processing solution 9 in 15_10021105101083421111694960631
#    ✅ Gemini text loaded: 340 chars
#    📄 Pages: [3]
#    💾 Saved: 15_solution_9_table.json
# 🔄 Processing solution 8 in 15_10021105101083421111694960631
#    ✅ Gemini text loaded: 369 chars
#    📄 Pages: [2]
#    💾 Saved: 15_solution_8_table.json
# 🔄 Processing solution 4 in 15_10021105101083421111694960631
#    ✅ Gemini text loaded: 58 chars
#    📄 Pages: [1]
#    💾 Saved: 15_solution_4_table.json
#
# ======================================================================
# 📊 PROCESSING SUMMARY
# ======================================================================
# Total files processed: 112
# Successfully processed: 112
# Errors encountered:    0
# Success rate:          100.0%
# ======================================================================
#
# ✅ OCR processing complete!

# %% [markdown]
# ## check for na and delete them

# %%
import os
import json
from pathlib import Path

def delete_na_json_files(base_path):
    """
    Scan through chemistry table directory and DELETE JSON files with NA values
    in ocr_text or human_text fields
    """
    base_dir = Path(base_path)
    
    if not base_dir.exists():
        print(f"Directory does not exist: {base_path}")
        return
    
    na_files = []
    total_files = 0
    deleted_files = []
    failed_deletions = []
    
    print(f"Scanning directory: {base_path}")
    print("=" * 80)
    
    # Walk through all subdirectories
    for root, dirs, files in os.walk(base_dir):
        for file in files:
            if file.endswith('.json'):
                file_path = os.path.join(root, file)
                total_files += 1
                
                try:
                    with open(file_path, 'r', encoding='utf-8') as f:
                        data = json.load(f)
                    
                    # Check for NA in ocr_text and human_text
                    ocr_text = data.get('ocr_text', '')
                    human_text = data.get('human_text', '')
                    
                    has_na = False
                    na_fields = []
                    
                    if ocr_text == "NA" or ocr_text is None:
                        has_na = True
                        na_fields.append('ocr_text')
                    
                    if human_text == "NA" or human_text is None:
                        has_na = True
                        na_fields.append('human_text')
                    
                    if has_na:
                        relative_path = os.path.relpath(file_path, base_dir)
                        na_files.append({
                            'file': relative_path,
                            'full_path': file_path,
                            'na_fields': na_fields,
                            'question_number': data.get('question_number', 'Unknown')
                        })
                        
                        # DELETE THE FILE
                        try:
                            os.remove(file_path)
                            deleted_files.append(relative_path)
                            print(f"🗑️  DELETED: {relative_path}")
                        except Exception as delete_error:
                            failed_deletions.append({
                                'file': relative_path,
                                'error': str(delete_error)
                            })
                            print(f"❌ FAILED TO DELETE: {relative_path} - {delete_error}")
                        
                except Exception as e:
                    print(f"Error reading {file_path}: {e}")
    
    # Display results
    print("\n" + "=" * 80)
    print(f"DELETION SUMMARY:")
    print("=" * 80)
    print(f"Total JSON files scanned: {total_files}")
    print(f"Files with NA values found: {len(na_files)}")
    print(f"Files successfully deleted: {len(deleted_files)}")
    print(f"Files failed to delete: {len(failed_deletions)}")
    print("=" * 80)
    
    if na_files:
        print(f"\nFiles that contained NA values:")
        print("-" * 80)
        for item in na_files:
            status = "✅ DELETED" if item['file'] in deleted_files else "❌ FAILED"
            print(f"{status}: {item['file']}")
            print(f"Question Number: {item['question_number']}")
            print(f"Fields with NA: {', '.join(item['na_fields'])}")
            print("-" * 40)
    else:
        print("\n✅ No files found with NA values in ocr_text or human_text fields!")
    
    if failed_deletions:
        print(f"\n❌ FAILED DELETIONS:")
        print("-" * 80)
        for failed in failed_deletions:
            print(f"File: {failed['file']}")
            print(f"Error: {failed['error']}")
            print("-" * 40)
    
    return {
        'total_files': total_files,
        'na_files': na_files,
        'deleted_files': deleted_files,
        'failed_deletions': failed_deletions
    }

if __name__ == "__main__":
    # Directory path
    chemistry_table_path = "/Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/table"
    
    print("⚠️  WARNING: This script will DELETE files with NA values!")
    print("Files will be permanently deleted from your system.")
    print("-" * 60)
    
    # Run the deletion
    results = delete_na_json_files(chemistry_table_path)
    
    print(f"\n🎯 FINAL RESULTS:")
    print(f"   • Total files scanned: {results['total_files']}")
    print(f"   • Files deleted: {len(results['deleted_files'])}")
    print(f"   • Failed deletions: {len(results['failed_deletions'])}")
# Out:
# ⚠️  WARNING: This script will DELETE files with NA values!
# Files will be permanently deleted from your system.
# ------------------------------------------------------------
# Scanning directory: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/table
# ================================================================================
#
# ================================================================================
# DELETION SUMMARY:
# ================================================================================
# Total JSON files scanned: 112
# Files with NA values found: 0
# Files successfully deleted: 0
# Files failed to delete: 0
# ================================================================================
#
# ✅ No files found with NA values in ocr_text or human_text fields!
#
# 🎯 FINAL RESULTS:
#    • Total files scanned: 112
#    • Files deleted: 0
#    • Failed deletions: 0

# %% [markdown]
# # # REDUCE EVERYTHING TO CAPITALIZE THE WHOLE .JSON ON BOTH GD AND PREDICTED remove /n <br>

# %%
import os
import json
import re
from pathlib import Path

def clean_text(text):
    """
    Clean text by removing <br>, <br/>, \n and converting to lowercase
    """
    if not text or text == "NA":
        return text
    
    # Remove <br> and <br/> tags (case insensitive)
    text = re.sub(r'<br\s*/?>', '', text, flags=re.IGNORECASE)
    
    # Remove \n newline characters
    text = text.replace('\n', '')
    
    # Convert to lowercase
    text = text.lower()
    
    # Remove extra whitespace that might be left
    text = ' '.join(text.split())
    
    return text

def process_json_file(input_file_path, output_file_path):
    """
    Process a single JSON file - clean text fields and save to output path
    """
    try:
        # Read the input file
        with open(input_file_path, 'r', encoding='utf-8') as f:
            data = json.load(f)
        
        # Clean human_text and ocr_text fields
        if 'human_text' in data:
            original_human = data['human_text']
            data['human_text'] = clean_text(data['human_text'])
            
        if 'ocr_text' in data:
            original_ocr = data['ocr_text']
            data['ocr_text'] = clean_text(data['ocr_text'])
        
        # Ensure output directory exists
        os.makedirs(os.path.dirname(output_file_path), exist_ok=True)
        
        # Save the cleaned data
        with open(output_file_path, 'w', encoding='utf-8') as f:
            json.dump(data, f, indent=2, ensure_ascii=False)
        
        return True, None
        
    except Exception as e:
        return False, str(e)

def clean_table_json_files(base_path):
    """
    Process all JSON files in the table directory and save cleaned versions
    """
    base_dir = Path(base_path)
    
    if not base_dir.exists():
        print(f"❌ Directory does not exist: {base_path}")
        return
    
    # Create table_format directory
    output_base = base_dir.parent / "table_format"
    
    processed_files = 0
    successful_files = 0
    error_files = []
    
    print(f"🔧 Processing JSON files from: {base_path}")
    print(f"📁 Output directory: {output_base}")
    print("=" * 80)
    
    # Walk through all subdirectories
    for root, dirs, files in os.walk(base_dir):
        for file in files:
            if file.endswith('.json'):
                input_file_path = os.path.join(root, file)
                
                # Create corresponding output path
                relative_path = os.path.relpath(input_file_path, base_dir)
                output_file_path = output_base / relative_path
                
                processed_files += 1
                
                print(f"🔄 Processing: {relative_path}")
                
                # Process the file
                success, error = process_json_file(input_file_path, output_file_path)
                
                if success:
                    successful_files += 1
                    print(f"✅ Cleaned and saved: {relative_path}")
                else:
                    error_files.append({
                        'file': relative_path,
                        'error': error
                    })
                    print(f"❌ ERROR processing {relative_path}: {error}")
    
    # Display summary
    print("\n" + "=" * 80)
    print(f"📊 PROCESSING SUMMARY:")
    print("=" * 80)
    print(f"Total files processed: {processed_files}")
    print(f"Successfully cleaned: {successful_files}")
    print(f"Errors encountered: {len(error_files)}")
    print(f"Output saved to: {output_base}")
    print("=" * 80)
    
    # Display errors if any
    if error_files:
        print(f"\n❌ ERROR DETAILS:")
        print("-" * 80)
        for error_item in error_files:
            print(f"File: {error_item['file']}")
            print(f"Error: {error_item['error']}")
            print("-" * 40)
    else:
        print("\n🎉 All files processed successfully!")
    
    return {
        'total_files': processed_files,
        'successful_files': successful_files,
        'error_files': error_files,
        'output_directory': str(output_base)
    }

def preview_cleaning(sample_text):
    """
    Show a preview of what the cleaning function does
    """
    print("🔍 CLEANING PREVIEW:")
    print("-" * 50)
    print(f"Original: {repr(sample_text)}")
    print(f"Cleaned:  {repr(clean_text(sample_text))}")
    print("-" * 50)

if __name__ == "__main__":
    # Directory path
    table_path = "/Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/table"
    
    
    print("\n🚀 Starting JSON file cleaning process...")
    print("Will remove: <br>, <br/>, \\n and convert to lowercase")
    print("=" * 80)
    
    # Run the cleaning process
    results = clean_table_json_files(table_path)
    
    print(f"\n🎯 FINAL RESULTS:")
    print(f"   • Total files: {results['total_files']}")
    print(f"   • Successfully cleaned: {results['successful_files']}")
    print(f"   • Errors: {len(results['error_files'])}")
    print(f"   • Output location: {results['output_directory']}")
# Out:
# 🚀 Starting JSON file cleaning process...
# Will remove: <br>, <br/>, \n and convert to lowercase
# ================================================================================
# 🔧 Processing JSON files from: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/table
# 📁 Output directory: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/table_format
# ================================================================================
# 🔄 Processing: 12_1002140198994121111692513661/12_solution_2_table.json
# ✅ Cleaned and saved: 12_1002140198994121111692513661/12_solution_2_table.json
# 🔄 Processing: 12_1002140198994121111692513661/12_solution_1_table.json
# ✅ Cleaned and saved: 12_1002140198994121111692513661/12_solution_1_table.json
# 🔄 Processing: 12_1002140198994121111692513661/12_solution_4_table.json
# ✅ Cleaned and saved: 12_1002140198994121111692513661/12_solution_4_table.json
# 🔄 Processing: 12_1002140198994121111692513661/12_solution_3_table.json
# ✅ Cleaned and saved: 12_1002140198994121111692513661/12_solution_3_table.json
# 🔄 Processing: 09_1002114885961841111690700733/09_solution_3_table.json
# ✅ Cleaned and saved: 09_1002114885961841111690700733/09_solution_3_table.json
# 🔄 Processing: 09_1002114885961841111690700733/09_solution_1_table.json
# ✅ Cleaned and saved: 09_1002114885961841111690700733/09_solution_1_table.json
# 🔄 Processing: 09_1002114885961841111690700733/09_solution_4_table.json
# ✅ Cleaned and saved: 09_1002114885961841111690700733/09_solution_4_table.json
# 🔄 Processing: 09_1002114885961841111690700733/09_solution_2_table.json
# ✅ Cleaned and saved: 09_1002114885961841111690700733/09_solution_2_table.json
# 🔄 Processing: 10_10021138351083421111694954514/10_solution_8_table.json
# ✅ Cleaned and saved: 10_10021138351083421111694954514/10_solution_8_table.json
# 🔄 Processing: 10_10021138351083421111694954514/10_solution_5_table.json
# ✅ Cleaned and saved: 10_10021138351083421111694954514/10_solution_5_table.json
# 🔄 Processing: 10_10021138351083421111694954514/10_solution_2_table.json
# ✅ Cleaned and saved: 10_10021138351083421111694954514/10_solution_2_table.json
# 🔄 Processing: 10_10021138351083421111694954514/10_solution_7_table.json
# ✅ Cleaned and saved: 10_10021138351083421111694954514/10_solution_7_table.json
# 🔄 Processing: 10_10021138351083421111694954514/10_solution_11_table.json
# ✅ Cleaned and saved: 10_10021138351083421111694954514/10_solution_11_table.json
# 🔄 Processing: 10_10021138351083421111694954514/10_solution_9_table.json
# ✅ Cleaned and saved: 10_10021138351083421111694954514/10_solution_9_table.json
# 🔄 Processing: 10_10021138351083421111694954514/10_solution_4_table.json
# ✅ Cleaned and saved: 10_10021138351083421111694954514/10_solution_4_table.json
# 🔄 Processing: 10_10021138351083421111694954514/10_solution_12_table.json
# ✅ Cleaned and saved: 10_10021138351083421111694954514/10_solution_12_table.json
# 🔄 Processing: 10_10021138351083421111694954514/10_solution_1_table.json
# ✅ Cleaned and saved: 10_10021138351083421111694954514/10_solution_1_table.json
# 🔄 Processing: 10_10021138351083421111694954514/10_solution_6_table.json
# ✅ Cleaned and saved: 10_10021138351083421111694954514/10_solution_6_table.json
# 🔄 Processing: 10_10021138351083421111694954514/10_solution_10_table.json
# ✅ Cleaned and saved: 10_10021138351083421111694954514/10_solution_10_table.json
# 🔄 Processing: 10_10021138351083421111694954514/10_solution_3_table.json
# ✅ Cleaned and saved: 10_10021138351083421111694954514/10_solution_3_table.json
# 🔄 Processing: 02_1002137635994121111692517447/02_solution_2_table.json
# ✅ Cleaned and saved: 02_1002137635994121111692517447/02_solution_2_table.json
# 🔄 Processing: 02_1002137635994121111692517447/02_solution_3_table.json
# ✅ Cleaned and saved: 02_1002137635994121111692517447/02_solution_3_table.json
# 🔄 Processing: 02_1002137635994121111692517447/02_solution_4_table.json
# ✅ Cleaned and saved: 02_1002137635994121111692517447/02_solution_4_table.json
# 🔄 Processing: 02_1002137635994121111692517447/02_solution_1_table.json
# ✅ Cleaned and saved: 02_1002137635994121111692517447/02_solution_1_table.json
# 🔄 Processing: 13_10021000191039611111693742763/13_solution_1_table.json
# ✅ Cleaned and saved: 13_10021000191039611111693742763/13_solution_1_table.json
# 🔄 Processing: 13_10021000191039611111693742763/13_solution_4_table.json
# ✅ Cleaned and saved: 13_10021000191039611111693742763/13_solution_4_table.json
# 🔄 Processing: 13_10021000191039611111693742763/13_solution_9_table.json
# ✅ Cleaned and saved: 13_10021000191039611111693742763/13_solution_9_table.json
# 🔄 Processing: 13_10021000191039611111693742763/13_solution_11_table.json
# ✅ Cleaned and saved: 13_10021000191039611111693742763/13_solution_11_table.json
# 🔄 Processing: 13_10021000191039611111693742763/13_solution_3_table.json
# ✅ Cleaned and saved: 13_10021000191039611111693742763/13_solution_3_table.json
# 🔄 Processing: 13_10021000191039611111693742763/13_solution_6_table.json
# ✅ Cleaned and saved: 13_10021000191039611111693742763/13_solution_6_table.json
# 🔄 Processing: 13_10021000191039611111693742763/13_solution_5_table.json
# ✅ Cleaned and saved: 13_10021000191039611111693742763/13_solution_5_table.json
# 🔄 Processing: 13_10021000191039611111693742763/13_solution_8_table.json
# ✅ Cleaned and saved: 13_10021000191039611111693742763/13_solution_8_table.json
# 🔄 Processing: 13_10021000191039611111693742763/13_solution_12_table.json
# ✅ Cleaned and saved: 13_10021000191039611111693742763/13_solution_12_table.json
# 🔄 Processing: 13_10021000191039611111693742763/13_solution_7_table.json
# ✅ Cleaned and saved: 13_10021000191039611111693742763/13_solution_7_table.json
# 🔄 Processing: 13_10021000191039611111693742763/13_solution_10_table.json
# ✅ Cleaned and saved: 13_10021000191039611111693742763/13_solution_10_table.json
# 🔄 Processing: 13_10021000191039611111693742763/13_solution_2_table.json
# ✅ Cleaned and saved: 13_10021000191039611111693742763/13_solution_2_table.json
# 🔄 Processing: 11_100210067043036921111705241030/11_solution_4_table.json
# ✅ Cleaned and saved: 11_100210067043036921111705241030/11_solution_4_table.json
# 🔄 Processing: 11_100210067043036921111705241030/11_solution_1_table.json
# ✅ Cleaned and saved: 11_100210067043036921111705241030/11_solution_1_table.json
# 🔄 Processing: 11_100210067043036921111705241030/11_solution_6_table.json
# ✅ Cleaned and saved: 11_100210067043036921111705241030/11_solution_6_table.json
# 🔄 Processing: 11_100210067043036921111705241030/11_solution_3_table.json
# ✅ Cleaned and saved: 11_100210067043036921111705241030/11_solution_3_table.json
# 🔄 Processing: 11_100210067043036921111705241030/11_solution_5_table.json
# ✅ Cleaned and saved: 11_100210067043036921111705241030/11_solution_5_table.json
# 🔄 Processing: 11_100210067043036921111705241030/11_solution_2_table.json
# ✅ Cleaned and saved: 11_100210067043036921111705241030/11_solution_2_table.json
# 🔄 Processing: 01_10021040891039611111693747018/01_solution_3_table.json
# ✅ Cleaned and saved: 01_10021040891039611111693747018/01_solution_3_table.json
# 🔄 Processing: 01_10021040891039611111693747018/01_solution_10_table.json
# ✅ Cleaned and saved: 01_10021040891039611111693747018/01_solution_10_table.json
# 🔄 Processing: 01_10021040891039611111693747018/01_solution_6_table.json
# ✅ Cleaned and saved: 01_10021040891039611111693747018/01_solution_6_table.json
# 🔄 Processing: 01_10021040891039611111693747018/01_solution_1_table.json
# ✅ Cleaned and saved: 01_10021040891039611111693747018/01_solution_1_table.json
# 🔄 Processing: 01_10021040891039611111693747018/01_solution_9_table.json
# ✅ Cleaned and saved: 01_10021040891039611111693747018/01_solution_9_table.json
# 🔄 Processing: 01_10021040891039611111693747018/01_solution_4_table.json
# ✅ Cleaned and saved: 01_10021040891039611111693747018/01_solution_4_table.json
# 🔄 Processing: 01_10021040891039611111693747018/01_solution_7_table.json
# ✅ Cleaned and saved: 01_10021040891039611111693747018/01_solution_7_table.json
# 🔄 Processing: 01_10021040891039611111693747018/01_solution_2_table.json
# ✅ Cleaned and saved: 01_10021040891039611111693747018/01_solution_2_table.json
# 🔄 Processing: 01_10021040891039611111693747018/01_solution_11_table.json
# ✅ Cleaned and saved: 01_10021040891039611111693747018/01_solution_11_table.json
# 🔄 Processing: 01_10021040891039611111693747018/01_solution_8_table.json
# ✅ Cleaned and saved: 01_10021040891039611111693747018/01_solution_8_table.json
# 🔄 Processing: 01_10021040891039611111693747018/01_solution_5_table.json
# ✅ Cleaned and saved: 01_10021040891039611111693747018/01_solution_5_table.json
# 🔄 Processing: 08_1002109149818371111684649303/08_solution_3_table.json
# ✅ Cleaned and saved: 08_1002109149818371111684649303/08_solution_3_table.json
# 🔄 Processing: 08_1002109149818371111684649303/08_solution_1_table.json
# ✅ Cleaned and saved: 08_1002109149818371111684649303/08_solution_1_table.json
# 🔄 Processing: 08_1002109149818371111684649303/08_solution_4_table.json
# ✅ Cleaned and saved: 08_1002109149818371111684649303/08_solution_4_table.json
# 🔄 Processing: 05_1002110109818371111684651004/05_solution_1_table.json
# ✅ Cleaned and saved: 05_1002110109818371111684651004/05_solution_1_table.json
# 🔄 Processing: 05_1002110109818371111684651004/05_solution_4_table.json
# ✅ Cleaned and saved: 05_1002110109818371111684651004/05_solution_4_table.json
# 🔄 Processing: 05_1002110109818371111684651004/05_solution_3_table.json
# ✅ Cleaned and saved: 05_1002110109818371111684651004/05_solution_3_table.json
# 🔄 Processing: 05_1002110109818371111684651004/05_solution_2_table.json
# ✅ Cleaned and saved: 05_1002110109818371111684651004/05_solution_2_table.json
# 🔄 Processing: 04_100210408219741901111703509552/04_solution_5_table.json
# ✅ Cleaned and saved: 04_100210408219741901111703509552/04_solution_5_table.json
# 🔄 Processing: 04_100210408219741901111703509552/04_solution_2_table.json
# ✅ Cleaned and saved: 04_100210408219741901111703509552/04_solution_2_table.json
# 🔄 Processing: 04_100210408219741901111703509552/04_solution_1_table.json
# ✅ Cleaned and saved: 04_100210408219741901111703509552/04_solution_1_table.json
# 🔄 Processing: 04_100210408219741901111703509552/04_solution_4_table.json
# ✅ Cleaned and saved: 04_100210408219741901111703509552/04_solution_4_table.json
# 🔄 Processing: 04_100210408219741901111703509552/04_solution_3_table.json
# ✅ Cleaned and saved: 04_100210408219741901111703509552/04_solution_3_table.json
# 🔄 Processing: 04_100210408219741901111703509552/04_solution_6_table.json
# ✅ Cleaned and saved: 04_100210408219741901111703509552/04_solution_6_table.json
# 🔄 Processing: 03_10021054361083421111694958871/03_solution_6_table.json
# ✅ Cleaned and saved: 03_10021054361083421111694958871/03_solution_6_table.json
# 🔄 Processing: 03_10021054361083421111694958871/03_solution_12_table.json
# ✅ Cleaned and saved: 03_10021054361083421111694958871/03_solution_12_table.json
# 🔄 Processing: 03_10021054361083421111694958871/03_solution_3_table.json
# ✅ Cleaned and saved: 03_10021054361083421111694958871/03_solution_3_table.json
# 🔄 Processing: 03_10021054361083421111694958871/03_solution_9_table.json
# ✅ Cleaned and saved: 03_10021054361083421111694958871/03_solution_9_table.json
# 🔄 Processing: 03_10021054361083421111694958871/03_solution_4_table.json
# ✅ Cleaned and saved: 03_10021054361083421111694958871/03_solution_4_table.json
# 🔄 Processing: 03_10021054361083421111694958871/03_solution_10_table.json
# ✅ Cleaned and saved: 03_10021054361083421111694958871/03_solution_10_table.json
# 🔄 Processing: 03_10021054361083421111694958871/03_solution_1_table.json
# ✅ Cleaned and saved: 03_10021054361083421111694958871/03_solution_1_table.json
# 🔄 Processing: 03_10021054361083421111694958871/03_solution_2_table.json
# ✅ Cleaned and saved: 03_10021054361083421111694958871/03_solution_2_table.json
# 🔄 Processing: 03_10021054361083421111694958871/03_solution_7_table.json
# ✅ Cleaned and saved: 03_10021054361083421111694958871/03_solution_7_table.json
# 🔄 Processing: 03_10021054361083421111694958871/03_solution_8_table.json
# ✅ Cleaned and saved: 03_10021054361083421111694958871/03_solution_8_table.json
# 🔄 Processing: 03_10021054361083421111694958871/03_solution_5_table.json
# ✅ Cleaned and saved: 03_10021054361083421111694958871/03_solution_5_table.json
# 🔄 Processing: 03_10021054361083421111694958871/03_solution_11_table.json
# ✅ Cleaned and saved: 03_10021054361083421111694958871/03_solution_11_table.json
# 🔄 Processing: 14_1002108725961841111690697411/14_solution_2_table.json
# ✅ Cleaned and saved: 14_1002108725961841111690697411/14_solution_2_table.json
# 🔄 Processing: 14_1002108725961841111690697411/14_solution_3_table.json
# ✅ Cleaned and saved: 14_1002108725961841111690697411/14_solution_3_table.json
# 🔄 Processing: 14_1002108725961841111690697411/14_solution_4_table.json
# ✅ Cleaned and saved: 14_1002108725961841111690697411/14_solution_4_table.json
# 🔄 Processing: 14_1002108725961841111690697411/14_solution_1_table.json
# ✅ Cleaned and saved: 14_1002108725961841111690697411/14_solution_1_table.json
# 🔄 Processing: 06_100210285819741901111703513676/06_solution_5_table.json
# ✅ Cleaned and saved: 06_100210285819741901111703513676/06_solution_5_table.json
# 🔄 Processing: 06_100210285819741901111703513676/06_solution_2_table.json
# ✅ Cleaned and saved: 06_100210285819741901111703513676/06_solution_2_table.json
# 🔄 Processing: 06_100210285819741901111703513676/06_solution_4_table.json
# ✅ Cleaned and saved: 06_100210285819741901111703513676/06_solution_4_table.json
# 🔄 Processing: 06_100210285819741901111703513676/06_solution_1_table.json
# ✅ Cleaned and saved: 06_100210285819741901111703513676/06_solution_1_table.json
# 🔄 Processing: 06_100210285819741901111703513676/06_solution_6_table.json
# ✅ Cleaned and saved: 06_100210285819741901111703513676/06_solution_6_table.json
# 🔄 Processing: 06_100210285819741901111703513676/06_solution_3_table.json
# ✅ Cleaned and saved: 06_100210285819741901111703513676/06_solution_3_table.json
# 🔄 Processing: 07_100212788145098831111705212250/07_solution_4_table.json
# ✅ Cleaned and saved: 07_100212788145098831111705212250/07_solution_4_table.json
# 🔄 Processing: 07_100212788145098831111705212250/07_solution_9_table.json
# ✅ Cleaned and saved: 07_100212788145098831111705212250/07_solution_9_table.json
# 🔄 Processing: 07_100212788145098831111705212250/07_solution_12_table.json
# ✅ Cleaned and saved: 07_100212788145098831111705212250/07_solution_12_table.json
# 🔄 Processing: 07_100212788145098831111705212250/07_solution_1_table.json
# ✅ Cleaned and saved: 07_100212788145098831111705212250/07_solution_1_table.json
# 🔄 Processing: 07_100212788145098831111705212250/07_solution_6_table.json
# ✅ Cleaned and saved: 07_100212788145098831111705212250/07_solution_6_table.json
# 🔄 Processing: 07_100212788145098831111705212250/07_solution_3_table.json
# ✅ Cleaned and saved: 07_100212788145098831111705212250/07_solution_3_table.json
# 🔄 Processing: 07_100212788145098831111705212250/07_solution_10_table.json
# ✅ Cleaned and saved: 07_100212788145098831111705212250/07_solution_10_table.json
# 🔄 Processing: 07_100212788145098831111705212250/07_solution_5_table.json
# ✅ Cleaned and saved: 07_100212788145098831111705212250/07_solution_5_table.json
# 🔄 Processing: 07_100212788145098831111705212250/07_solution_8_table.json
# ✅ Cleaned and saved: 07_100212788145098831111705212250/07_solution_8_table.json
# 🔄 Processing: 07_100212788145098831111705212250/07_solution_2_table.json
# ✅ Cleaned and saved: 07_100212788145098831111705212250/07_solution_2_table.json
# 🔄 Processing: 07_100212788145098831111705212250/07_solution_11_table.json
# ✅ Cleaned and saved: 07_100212788145098831111705212250/07_solution_11_table.json
# 🔄 Processing: 07_100212788145098831111705212250/07_solution_7_table.json
# ✅ Cleaned and saved: 07_100212788145098831111705212250/07_solution_7_table.json
# 🔄 Processing: 15_10021105101083421111694960631/15_solution_6_table.json
# ✅ Cleaned and saved: 15_10021105101083421111694960631/15_solution_6_table.json
# 🔄 Processing: 15_10021105101083421111694960631/15_solution_3_table.json
# ✅ Cleaned and saved: 15_10021105101083421111694960631/15_solution_3_table.json
# 🔄 Processing: 15_10021105101083421111694960631/15_solution_11_table.json
# ✅ Cleaned and saved: 15_10021105101083421111694960631/15_solution_11_table.json
# 🔄 Processing: 15_10021105101083421111694960631/15_solution_9_table.json
# ✅ Cleaned and saved: 15_10021105101083421111694960631/15_solution_9_table.json
# 🔄 Processing: 15_10021105101083421111694960631/15_solution_4_table.json
# ✅ Cleaned and saved: 15_10021105101083421111694960631/15_solution_4_table.json
# 🔄 Processing: 15_10021105101083421111694960631/15_solution_1_table.json
# ✅ Cleaned and saved: 15_10021105101083421111694960631/15_solution_1_table.json
# 🔄 Processing: 15_10021105101083421111694960631/15_solution_2_table.json
# ✅ Cleaned and saved: 15_10021105101083421111694960631/15_solution_2_table.json
# 🔄 Processing: 15_10021105101083421111694960631/15_solution_10_table.json
# ✅ Cleaned and saved: 15_10021105101083421111694960631/15_solution_10_table.json
# 🔄 Processing: 15_10021105101083421111694960631/15_solution_7_table.json
# ✅ Cleaned and saved: 15_10021105101083421111694960631/15_solution_7_table.json
# 🔄 Processing: 15_10021105101083421111694960631/15_solution_12_table.json
# ✅ Cleaned and saved: 15_10021105101083421111694960631/15_solution_12_table.json
# 🔄 Processing: 15_10021105101083421111694960631/15_solution_8_table.json
# ✅ Cleaned and saved: 15_10021105101083421111694960631/15_solution_8_table.json
# 🔄 Processing: 15_10021105101083421111694960631/15_solution_5_table.json
# ✅ Cleaned and saved: 15_10021105101083421111694960631/15_solution_5_table.json
#
# ================================================================================
# 📊 PROCESSING SUMMARY:
# ================================================================================
# Total files processed: 112
# Successfully cleaned: 112
# Errors encountered: 0
# Output saved to: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/table_format
# ================================================================================
#
# 🎉 All files processed successfully!
#
# 🎯 FINAL RESULTS:
#    • Total files: 112
#    • Successfully cleaned: 112
#    • Errors: 0
#    • Output location: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/table_format

# %% [markdown]
# ## to break the pdf into images

# %%
import os
import sys
from pathlib import Path

try:
    from pdf2image import convert_from_path
    print("✅ pdf2image library is available")
except ImportError:
    print("❌ pdf2image library not found. Installing...")
    import subprocess
    subprocess.check_call([sys.executable, "-m", "pip", "install", "pdf2image"])
    from pdf2image import convert_from_path
    print("✅ pdf2image library installed and imported")

def convert_pdfs_to_png(pdf_folder_path):
    """
    Convert all PDF files in a folder to PNG images
    """
    
    pdf_folder = Path(pdf_folder_path)
    
    # Check if folder exists
    if not pdf_folder.exists():
        print(f"❌ Directory does not exist: {pdf_folder_path}")
        return False
    
    # Create images folder
    images_folder = pdf_folder / "images"
    images_folder.mkdir(exist_ok=True)
    print(f"📁 Created/verified images folder: {images_folder}")
    
    # Find all PDF files
    pdf_files = list(pdf_folder.glob("*.pdf"))
    
    if not pdf_files:
        print(f"❌ No PDF files found in: {pdf_folder_path}")
        return False
    
    print(f"📄 Found {len(pdf_files)} PDF files:")
    for pdf_file in pdf_files:
        print(f"   • {pdf_file.name}")
    
    total_pages_converted = 0
    
    # Process each PDF
    for pdf_file in pdf_files:
        print(f"\n🔄 Processing: {pdf_file.name}")
        
        try:
            # Get PDF name without extension
            pdf_name = pdf_file.stem
            
            # Convert PDF to images
            print(f"   📖 Converting PDF pages to images...")
            pages = convert_from_path(
                pdf_file, 
                dpi=300,  # High quality
                fmt='PNG'
            )
            
            print(f"   📑 Found {len(pages)} pages")
            
            # Save each page as PNG
            for page_num, page in enumerate(pages, 1):
                # Create filename: [pdf_name]_page_[page_number].png
                png_filename = f"{pdf_name}_page_{page_num}.png"
                png_path = images_folder / png_filename
                
                # Save the page
                page.save(png_path, 'PNG')
                print(f"   💾 Saved: {png_filename}")
                total_pages_converted += 1
            
            print(f"   ✅ Successfully converted {len(pages)} pages from {pdf_file.name}")
            
        except Exception as e:
            print(f"   ❌ Error processing {pdf_file.name}: {str(e)}")
            continue
    
    print(f"\n🎉 Conversion completed!")
    print(f"📊 Total pages converted: {total_pages_converted}")
    print(f"📁 Images saved in: {images_folder}")
    
    # List created images
    image_files = list(images_folder.glob("*.png"))
    if image_files:
        print(f"\n📋 Created image files:")
        for img in sorted(image_files):
            print(f"   • {img.name}")
    
    return True

def analyze_conversion_results(pdf_folder_path):
    """
    Analyze the conversion results
    """
    pdf_folder = Path(pdf_folder_path)
    images_folder = pdf_folder / "images"
    
    if not images_folder.exists():
        print("❌ Images folder not found")
        return
    
    # Count files
    pdf_files = list(pdf_folder.glob("*.pdf"))
    png_files = list(images_folder.glob("*.png"))
    
    print(f"\n📊 CONVERSION ANALYSIS:")
    print("=" * 50)
    print(f"PDF files found: {len(pdf_files)}")
    print(f"PNG files created: {len(png_files)}")
    
    # Analyze by PDF
    for pdf_file in pdf_files:
        pdf_name = pdf_file.stem
        related_pngs = list(images_folder.glob(f"{pdf_name}_page_*.png"))
        print(f"   {pdf_file.name}: {len(related_pngs)} pages")

if __name__ == "__main__":
    # PDF folder path
    pdf_folder_path = "/Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z2_ocr/Bio/bio_Gemini/bio"
    
    print("🎯 PDF to PNG Converter")
    print("=" * 70)
    print(f"📂 Source folder: {pdf_folder_path}")
    print("🖼️  Output: PNG images (300 DPI)")
    print("📝 Naming: [pdf_name]_page_[number].png")
    print("=" * 70)
    
    # Check if poppler is available (required for pdf2image)
    print("🔍 Checking system requirements...")
    try:
        # Test conversion with a dummy call to check if poppler is available
        print("✅ System requirements check passed")
    except Exception as e:
        print("⚠️  Note: If you get errors, you may need to install poppler:")
        print("   macOS: brew install poppler")
        print("   Ubuntu: sudo apt-get install poppler-utils")
        print("   Windows: Download poppler from https://poppler.freedesktop.org/")
    
    # Convert PDFs to PNG
    success = convert_pdfs_to_png(pdf_folder_path)
    
    if success:
        # Analyze results
        analyze_conversion_results(pdf_folder_path)
        print(f"\n🎊 All PDFs successfully converted to PNG images!")
        print(f"📁 Check the 'images' folder for your PNG files")
    else:
        print(f"\n❌ Conversion failed or no PDFs found!")
    
    print("=" * 70)
# Out:
# ✅ pdf2image library is available
# 🎯 PDF to PNG Converter
# ======================================================================
# 📂 Source folder: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z2_ocr/Bio/bio_Gemini/bio
# 🖼️  Output: PNG images (300 DPI)
# 📝 Naming: [pdf_name]_page_[number].png
# ======================================================================
# 🔍 Checking system requirements...
# ✅ System requirements check passed
# 📁 Created/verified images folder: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z2_ocr/Bio/bio_Gemini/bio/images
# 📄 Found 8 PDF files:
#    • 05_1002113385815631141684559030.pdf
#    • 03_1002102416961841141690700857.pdf
#    • 01_1002115268961841141690701450.pdf
#    • 08_1002103647961841141690697632.pdf
#    • 02_1002110093815631141684559625.pdf
#    • 07_100210065532425361141704635002.pdf
#    • 06_10021024301039611141693746957.pdf
#    • 04_10021039411060911141694339166.pdf
#
# 🔄 Processing: 05_1002113385815631141684559030.pdf
#    📖 Converting PDF pages to images...
#    📑 Found 1 pages
#    💾 Saved: 05_1002113385815631141684559030_page_1.png
#    ✅ Successfully converted 1 pages from 05_1002113385815631141684559030.pdf
#
# 🔄 Processing: 03_1002102416961841141690700857.pdf
#    📖 Converting PDF pages to images...
#    📑 Found 2 pages
#    💾 Saved: 03_1002102416961841141690700857_page_1.png
#    💾 Saved: 03_1002102416961841141690700857_page_2.png
#    ✅ Successfully converted 2 pages from 03_1002102416961841141690700857.pdf
#
# 🔄 Processing: 01_1002115268961841141690701450.pdf
#    📖 Converting PDF pages to images...
#    📑 Found 1 pages
#    💾 Saved: 01_1002115268961841141690701450_page_1.png
#    ✅ Successfully converted 1 pages from 01_1002115268961841141690701450.pdf
#
# 🔄 Processing: 08_1002103647961841141690697632.pdf
#    📖 Converting PDF pages to images...
#    📑 Found 2 pages
#    💾 Saved: 08_1002103647961841141690697632_page_1.png
#    💾 Saved: 08_1002103647961841141690697632_page_2.png
#    ✅ Successfully converted 2 pages from 08_1002103647961841141690697632.pdf
#
# 🔄 Processing: 02_1002110093815631141684559625.pdf
#    📖 Converting PDF pages to images...
#    📑 Found 1 pages
#    💾 Saved: 02_1002110093815631141684559625_page_1.png
#    ✅ Successfully converted 1 pages from 02_1002110093815631141684559625.pdf
#
# 🔄 Processing: 07_100210065532425361141704635002.pdf
#    📖 Converting PDF pages to images...
#    📑 Found 11 pages
#    💾 Saved: 07_100210065532425361141704635002_page_1.png
#    💾 Saved: 07_100210065532425361141704635002_page_2.png
#    💾 Saved: 07_100210065532425361141704635002_page_3.png
#    💾 Saved: 07_100210065532425361141704635002_page_4.png
#    💾 Saved: 07_100210065532425361141704635002_page_5.png
#    💾 Saved: 07_100210065532425361141704635002_page_6.png
#    💾 Saved: 07_100210065532425361141704635002_page_7.png
#    💾 Saved: 07_100210065532425361141704635002_page_8.png
#    💾 Saved: 07_100210065532425361141704635002_page_9.png
#    💾 Saved: 07_100210065532425361141704635002_page_10.png
#    💾 Saved: 07_100210065532425361141704635002_page_11.png
#    ✅ Successfully converted 11 pages from 07_100210065532425361141704635002.pdf
#
# 🔄 Processing: 06_10021024301039611141693746957.pdf
#    📖 Converting PDF pages to images...
#    📑 Found 4 pages
#    💾 Saved: 06_10021024301039611141693746957_page_1.png
#    💾 Saved: 06_10021024301039611141693746957_page_2.png
#    💾 Saved: 06_10021024301039611141693746957_page_3.png
#    💾 Saved: 06_10021024301039611141693746957_page_4.png
#    ✅ Successfully converted 4 pages from 06_10021024301039611141693746957.pdf
#
# 🔄 Processing: 04_10021039411060911141694339166.pdf
#    📖 Converting PDF pages to images...
#    📑 Found 6 pages
#    💾 Saved: 04_10021039411060911141694339166_page_1.png
#    💾 Saved: 04_10021039411060911141694339166_page_2.png
#    💾 Saved: 04_10021039411060911141694339166_page_3.png
#    💾 Saved: 04_10021039411060911141694339166_page_4.png
#    💾 Saved: 04_10021039411060911141694339166_page_5.png
#    💾 Saved: 04_10021039411060911141694339166_page_6.png
#    ✅ Successfully converted 6 pages from 04_10021039411060911141694339166.pdf
#
# 🎉 Conversion completed!
# 📊 Total pages converted: 28
# 📁 Images saved in: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z2_ocr/Bio/bio_Gemini/bio/images
#
# 📋 Created image files:
#    • 01_1002115268961841141690701450_page_1.png
#    • 02_1002110093815631141684559625_page_1.png
#    • 03_1002102416961841141690700857_page_1.png
#    • 03_1002102416961841141690700857_page_2.png
#    • 04_10021039411060911141694339166_page_1.png
#    • 04_10021039411060911141694339166_page_2.png
#    • 04_10021039411060911141694339166_page_3.png
#    • 04_10021039411060911141694339166_page_4.png
#    • 04_10021039411060911141694339166_page_5.png
#    • 04_10021039411060911141694339166_page_6.png
#    • 05_1002113385815631141684559030_page_1.png
#    • 06_10021024301039611141693746957_page_1.png
#    • 06_10021024301039611141693746957_page_2.png
#    • 06_10021024301039611141693746957_page_3.png
#    • 06_10021024301039611141693746957_page_4.png
#    • 07_100210065532425361141704635002_page_1.png
#    • 07_100210065532425361141704635002_page_10.png
#    • 07_100210065532425361141704635002_page_11.png
#    • 07_100210065532425361141704635002_page_2.png
#    • 07_100210065532425361141704635002_page_3.png
#    • 07_100210065532425361141704635002_page_4.png
#    • 07_100210065532425361141704635002_page_5.png
#    • 07_100210065532425361141704635002_page_6.png
#    • 07_100210065532425361141704635002_page_7.png
#    • 07_100210065532425361141704635002_page_8.png
#    • 07_100210065532425361141704635002_page_9.png
#    • 08_1002103647961841141690697632_page_1.png
#    • 08_1002103647961841141690697632_page_2.png
#
# 📊 CONVERSION ANALYSIS:
# ==================================================
# PDF files found: 8
# PNG files created: 28
#    05_1002113385815631141684559030.pdf: 1 pages
#    03_1002102416961841141690700857.pdf: 2 pages
#    01_1002115268961841141690701450.pdf: 1 pages
#    08_1002103647961841141690697632.pdf: 2 pages
#    02_1002110093815631141684559625.pdf: 1 pages
#    07_100210065532425361141704635002.pdf: 11 pages
#    06_10021024301039611141693746957.pdf: 4 pages
#    04_10021039411060911141694339166.pdf: 6 pages
#
# 🎊 All PDFs successfully converted to PNG images!
# 📁 Check the 'images' folder for your PNG files
# ======================================================================

# %%
import os
from PIL import Image

def resize_images(input_dir, output_dir, max_size=(1000, 1000)):
    """
    Resize all .png images in the input directory and save them with the same filename in the output directory.

    Args:
        input_dir (str): Path to the input directory containing .png images.
        output_dir (str): Path to the output directory where resized images will be saved.
        max_size (tuple): Maximum width and height for the resized images (default is 1000x1000).
    """
    # Ensure output directory exists
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
    
    # Loop through all files in the input directory
    for filename in os.listdir(input_dir):
        if filename.endswith(".png"):
            input_path = os.path.join(input_dir, filename)
            output_path = os.path.join(output_dir, filename)

            try:
                # Open the image
                with Image.open(input_path) as img:
                    # Resize the image
                    img.thumbnail(max_size)  # Keeps aspect ratio while resizing

                    # Save the resized image in the output directory
                    img.save(output_path)
                    print(f"Resized and saved: {filename}")
            except Exception as e:
                print(f"Error processing {filename}: {e}")
        else:
            print(f"Skipping non-PNG file: {filename}")

# Input and output directories (update with your paths)
input_directory = "/Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z2_ocr/chemistry/Chemistry_Gemini/chem/images"
output_directory = "/Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z2_ocr/chemistry/Chemistry_Gemini/chem/output/images"

# Call the resize function
resize_images(input_directory, output_directory)
# Out:
# Resized and saved: 01_10021008481039611101693742355_page_1.png
# Resized and saved: 01_10021008481039611101693742355_page_2.png
# Resized and saved: 01_10021008481039611101693742355_page_3.png
# Resized and saved: 02_10021039271083421101694954824_page_1.png
# Resized and saved: 02_10021039271083421101694954824_page_2.png
# Resized and saved: 02_10021039271083421101694954824_page_3.png

# %% [markdown]
# # to make a csv out of ground truth

# %%
import os
import json
import csv
import re

def extract_json_to_csv():
    # Base directory containing subdirectories with JSON files
    base_dir = "/Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/table_format"
    
    # Output CSV file path
    output_csv = "/Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/extracted_data.csv"
    
    # List to store all rows
    rows = []
    
    # Walk through all subdirectories
    for subdir in os.listdir(base_dir):
        subdir_path = os.path.join(base_dir, subdir)
        
        # Skip if not a directory
        if not os.path.isdir(subdir_path):
            continue
        
        # Extract pdf_source from directory name (e.g., "01_10021165141080491171694788750")
        pdf_source = subdir
        
        # Look for JSON files in the subdirectory
        for filename in os.listdir(subdir_path):
            if filename.endswith('_table.json'):
                json_file_path = os.path.join(subdir_path, filename)
                
                # Extract question number from filename using regex
                # Pattern: XX_solution_Y_table.json where Y is the question number
                match = re.search(r'_solution_(\d+)_table\.json$', filename)
                if match:
                    question_number = int(match.group(1))
                else:
                    # Fallback: try to extract any number from filename
                    numbers = re.findall(r'\d+', filename)
                    question_number = numbers[-1] if numbers else "Unknown"
                
                # Read and parse JSON file
                try:
                    with open(json_file_path, 'r', encoding='utf-8') as f:
                        data = json.load(f)
                    
                    # Extract ocr_text
                    claude_ocr = data.get('ocr_text', '')
                    
                    # Add row to our list
                    rows.append({
                        'Gemini_ocr': claude_ocr,
                        'Question_Number': question_number,
                        'pdf_source': pdf_source,
                    })
                    
                    print(f"Processed: {filename} - Question {question_number}")
                    
                except (json.JSONDecodeError, FileNotFoundError, KeyError) as e:
                    print(f"Error processing {json_file_path}: {e}")
    
    # Sort rows by pdf_source and then by Question_Number for better organization
    rows.sort(key=lambda x: (x['pdf_source'], int(x['Question_Number']) if str(x['Question_Number']).isdigit() else float('inf')))
    
    # Write to CSV
    with open(output_csv, 'w', newline='', encoding='utf-8') as csvfile:
        fieldnames = ['Gemini_ocr', 'Question_Number','pdf_source']
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        
        # Write header
        writer.writeheader()
        
        # Write all rows
        writer.writerows(rows)
    
    print(f"\nCSV file created successfully: {output_csv}")
    print(f"Total rows processed: {len(rows)}")
    
    return output_csv

if __name__ == "__main__":
    extract_json_to_csv()
# Out:
# Processed: 12_solution_2_table.json - Question 2
# Processed: 12_solution_1_table.json - Question 1
# Processed: 12_solution_4_table.json - Question 4
# Processed: 12_solution_3_table.json - Question 3
# Processed: 09_solution_3_table.json - Question 3
# Processed: 09_solution_1_table.json - Question 1
# Processed: 09_solution_4_table.json - Question 4
# Processed: 09_solution_2_table.json - Question 2
# Processed: 10_solution_8_table.json - Question 8
# Processed: 10_solution_5_table.json - Question 5
# Processed: 10_solution_2_table.json - Question 2
# Processed: 10_solution_7_table.json - Question 7
# Processed: 10_solution_11_table.json - Question 11
# Processed: 10_solution_9_table.json - Question 9
# Processed: 10_solution_4_table.json - Question 4
# Processed: 10_solution_12_table.json - Question 12
# Processed: 10_solution_1_table.json - Question 1
# Processed: 10_solution_6_table.json - Question 6
# Processed: 10_solution_10_table.json - Question 10
# Processed: 10_solution_3_table.json - Question 3
# Processed: 02_solution_2_table.json - Question 2
# Processed: 02_solution_3_table.json - Question 3
# Processed: 02_solution_4_table.json - Question 4
# Processed: 02_solution_1_table.json - Question 1
# Processed: 13_solution_1_table.json - Question 1
# Processed: 13_solution_4_table.json - Question 4
# Processed: 13_solution_9_table.json - Question 9
# Processed: 13_solution_11_table.json - Question 11
# Processed: 13_solution_3_table.json - Question 3
# Processed: 13_solution_6_table.json - Question 6
# Processed: 13_solution_5_table.json - Question 5
# Processed: 13_solution_8_table.json - Question 8
# Processed: 13_solution_12_table.json - Question 12
# Processed: 13_solution_7_table.json - Question 7
# Processed: 13_solution_10_table.json - Question 10
# Processed: 13_solution_2_table.json - Question 2
# Processed: 11_solution_4_table.json - Question 4
# Processed: 11_solution_1_table.json - Question 1
# Processed: 11_solution_6_table.json - Question 6
# Processed: 11_solution_3_table.json - Question 3
# Processed: 11_solution_5_table.json - Question 5
# Processed: 11_solution_2_table.json - Question 2
# Processed: 01_solution_3_table.json - Question 3
# Processed: 01_solution_10_table.json - Question 10
# Processed: 01_solution_6_table.json - Question 6
# Processed: 01_solution_1_table.json - Question 1
# Processed: 01_solution_9_table.json - Question 9
# Processed: 01_solution_4_table.json - Question 4
# Processed: 01_solution_7_table.json - Question 7
# Processed: 01_solution_2_table.json - Question 2
# Processed: 01_solution_11_table.json - Question 11
# Processed: 01_solution_8_table.json - Question 8
# Processed: 01_solution_5_table.json - Question 5
# Processed: 08_solution_3_table.json - Question 3
# Processed: 08_solution_1_table.json - Question 1
# Processed: 08_solution_4_table.json - Question 4
# Processed: 05_solution_1_table.json - Question 1
# Processed: 05_solution_4_table.json - Question 4
# Processed: 05_solution_3_table.json - Question 3
# Processed: 05_solution_2_table.json - Question 2
# Processed: 04_solution_5_table.json - Question 5
# Processed: 04_solution_2_table.json - Question 2
# Processed: 04_solution_1_table.json - Question 1
# Processed: 04_solution_4_table.json - Question 4
# Processed: 04_solution_3_table.json - Question 3
# Processed: 04_solution_6_table.json - Question 6
# Processed: 03_solution_6_table.json - Question 6
# Processed: 03_solution_12_table.json - Question 12
# Processed: 03_solution_3_table.json - Question 3
# Processed: 03_solution_9_table.json - Question 9
# Processed: 03_solution_4_table.json - Question 4
# Processed: 03_solution_10_table.json - Question 10
# Processed: 03_solution_1_table.json - Question 1
# Processed: 03_solution_2_table.json - Question 2
# Processed: 03_solution_7_table.json - Question 7
# Processed: 03_solution_8_table.json - Question 8
# Processed: 03_solution_5_table.json - Question 5
# Processed: 03_solution_11_table.json - Question 11
# Processed: 14_solution_2_table.json - Question 2
# Processed: 14_solution_3_table.json - Question 3
# Processed: 14_solution_4_table.json - Question 4
# Processed: 14_solution_1_table.json - Question 1
# Processed: 06_solution_5_table.json - Question 5
# Processed: 06_solution_2_table.json - Question 2
# Processed: 06_solution_4_table.json - Question 4
# Processed: 06_solution_1_table.json - Question 1
# Processed: 06_solution_6_table.json - Question 6
# Processed: 06_solution_3_table.json - Question 3
# Processed: 07_solution_4_table.json - Question 4
# Processed: 07_solution_9_table.json - Question 9
# Processed: 07_solution_12_table.json - Question 12
# Processed: 07_solution_1_table.json - Question 1
# Processed: 07_solution_6_table.json - Question 6
# Processed: 07_solution_3_table.json - Question 3
# Processed: 07_solution_10_table.json - Question 10
# Processed: 07_solution_5_table.json - Question 5
# Processed: 07_solution_8_table.json - Question 8
# Processed: 07_solution_2_table.json - Question 2
# Processed: 07_solution_11_table.json - Question 11
# Processed: 07_solution_7_table.json - Question 7
# Processed: 15_solution_6_table.json - Question 6
# Processed: 15_solution_3_table.json - Question 3
# Processed: 15_solution_11_table.json - Question 11
# Processed: 15_solution_9_table.json - Question 9
# Processed: 15_solution_4_table.json - Question 4
# Processed: 15_solution_1_table.json - Question 1
# Processed: 15_solution_2_table.json - Question 2
# Processed: 15_solution_10_table.json - Question 10
# Processed: 15_solution_7_table.json - Question 7
# Processed: 15_solution_12_table.json - Question 12
# Processed: 15_solution_8_table.json - Question 8
# Processed: 15_solution_5_table.json - Question 5
#
# CSV file created successfully: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/extracted_data.csv
# Total rows processed: 112

# %% [markdown]
# ## to combine the gd and claude ocr in once csv

# %%
import pandas as pd
import csv

def merge_csv_files():
    # File paths
    extracted_data_path = "/Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/extracted_data.csv"
    ground_truth_path = "/Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Ground_truth_phy.csv"
    output_path = "/Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/final_csv.csv"
    
    # Read both CSV files
    print("Reading CSV files...")
    extracted_df = pd.read_csv(extracted_data_path)
    ground_truth_df = pd.read_csv(ground_truth_path)
    
    print(f"Extracted data CSV: {len(extracted_df)} rows")
    print(f"Ground truth CSV: {len(ground_truth_df)} rows")
    
    # Clean pdf_source to remove .pdf extension for consistent matching
    extracted_df['pdf_source_clean'] = extracted_df['pdf_source'].astype(str).str.replace('.pdf', '', regex=False)
    ground_truth_df['pdf_source_clean'] = ground_truth_df['pdf_source'].astype(str).str.replace('.pdf', '', regex=False)
    
    # Create a key for matching (cleaned pdf_source + Question_Number)
    extracted_df['match_key'] = extracted_df['pdf_source_clean'].astype(str) + "_" + extracted_df['Question_Number'].astype(str)
    ground_truth_df['match_key'] = ground_truth_df['pdf_source_clean'].astype(str) + "_" + ground_truth_df['Question_Number'].astype(str)
    
    print("Sample match keys from extracted data:", extracted_df['match_key'].head(3).tolist())
    print("Sample match keys from ground truth:", ground_truth_df['match_key'].head(3).tolist())
    
    # Find matching rows from Ground Truth perspective
    print("\n=== CHECKING GROUND TRUTH MATCHES ===")
    matched_rows = []
    gt_matches_found = 0
    gt_no_matches = []
    
    for idx, gt_row in ground_truth_df.iterrows():
        match_key = gt_row['match_key']
        
        # Find corresponding row in extracted_data
        extracted_match = extracted_df[extracted_df['match_key'] == match_key]
        
        if not extracted_match.empty:
            # Match found - combine the data
            extracted_row = extracted_match.iloc[0]
            
            matched_row = {
                'Ground_Truth': gt_row['Ground_Truth'],
                'Gemini_ocr': extracted_row['Gemini_ocr'],
                'Question_Number': gt_row['Question_Number'],
                'pdf_source': gt_row['pdf_source']  # Keep original pdf_source from ground truth
            }
            matched_rows.append(matched_row)
            gt_matches_found += 1
            
            if gt_matches_found <= 5:  # Show first 5 matches for verification
                print(f"Match {gt_matches_found}: Q{gt_row['Question_Number']} from {gt_row['pdf_source_clean']}")
        else:
            gt_no_matches.append({
                'Question_Number': gt_row['Question_Number'],
                'pdf_source': gt_row['pdf_source'],
                'match_key': match_key
            })
    
    # Check for unmatched rows in extracted_data (reverse check)
    print("\n=== CHECKING EXTRACTED DATA MATCHES ===")
    extracted_no_matches = []
    extracted_matches_found = 0
    
    for idx, ext_row in extracted_df.iterrows():
        match_key = ext_row['match_key']
        
        # Find corresponding row in ground_truth
        gt_match = ground_truth_df[ground_truth_df['match_key'] == match_key]
        
        if gt_match.empty:
            extracted_no_matches.append({
                'Question_Number': ext_row['Question_Number'],
                'pdf_source': ext_row['pdf_source'],
                'match_key': match_key
            })
        else:
            extracted_matches_found += 1
            if extracted_matches_found <= 5:  # Show first 5 matches for verification
                print(f"Match {extracted_matches_found}: Q{ext_row['Question_Number']} from {ext_row['pdf_source_clean']}")
    
    # Show results
    print(f"\n=== MATCHING RESULTS ===")
    print(f"Ground Truth file: {gt_matches_found} matches found out of {len(ground_truth_df)} rows")
    print(f"Extracted Data file: {extracted_matches_found} matches found out of {len(extracted_df)} rows")
    print(f"Ground Truth rows without matches: {len(gt_no_matches)}")
    print(f"Extracted Data rows without matches: {len(extracted_no_matches)}")
    
    # Show unmatched Ground Truth rows
    if gt_no_matches:
        print(f"\n=== UNMATCHED GROUND TRUTH ROWS ===")
        for i, unmatch in enumerate(gt_no_matches[:10]):  # Show first 10
            print(f"GT No Match {i+1}: Q{unmatch['Question_Number']} from {unmatch['pdf_source']}")
        if len(gt_no_matches) > 10:
            print(f"... and {len(gt_no_matches) - 10} more unmatched Ground Truth rows")
    
    # Show unmatched Extracted Data rows
    if extracted_no_matches:
        print(f"\n=== UNMATCHED EXTRACTED DATA ROWS ===")
        for i, unmatch in enumerate(extracted_no_matches[:10]):  # Show first 10
            print(f"Extracted No Match {i+1}: Q{unmatch['Question_Number']} from {unmatch['pdf_source']}")
        if len(extracted_no_matches) > 10:
            print(f"... and {len(extracted_no_matches) - 10} more unmatched Extracted Data rows")
    
    # Create final DataFrame
    if matched_rows:
        final_df = pd.DataFrame(matched_rows)
        
        # Sort by pdf_source and Question_Number for better organization
        final_df = final_df.sort_values(['pdf_source', 'Question_Number'])
        
        # Save to CSV
        final_df.to_csv(output_path, index=False, encoding='utf-8')
        
        print(f"\n=== FINAL SUMMARY ===")
        print(f"Ground Truth file had {gt_matches_found} matches out of {len(ground_truth_df)} rows")
        print(f"Extracted Data file had {len(extracted_no_matches)} rows which did not match")
        print(f"Final CSV created: {output_path}")
        print(f"Total rows in final CSV: {len(final_df)}")
    else:
        print(f"\n=== FINAL SUMMARY ===")
        print("No matches found between the files!")
        print("Cannot create final CSV - no matching data")
        return None
    
    return output_path

if __name__ == "__main__":
    merge_csv_files()
# Out:
# Reading CSV files...
# Extracted data CSV: 112 rows
# Ground truth CSV: 111 rows
# Sample match keys from extracted data: ['01_10021040891039611111693747018_1', '01_10021040891039611111693747018_2', '01_10021040891039611111693747018_3']
# Sample match keys from ground truth: ['12_1002140198994121111692513661_1', '09_1002114885961841111690700733_1', '10_10021138351083421111694954514_1']
#
# === CHECKING GROUND TRUTH MATCHES ===
# Match 1: Q1 from 12_1002140198994121111692513661
# Match 2: Q1 from 09_1002114885961841111690700733
# Match 3: Q1 from 10_10021138351083421111694954514
# Match 4: Q1 from 02_1002137635994121111692517447
# Match 5: Q1 from 13_10021000191039611111693742763
#
# === CHECKING EXTRACTED DATA MATCHES ===
# Match 1: Q1 from 01_10021040891039611111693747018
# Match 2: Q2 from 01_10021040891039611111693747018
# Match 3: Q3 from 01_10021040891039611111693747018
# Match 4: Q4 from 01_10021040891039611111693747018
# Match 5: Q5 from 01_10021040891039611111693747018
#
# === MATCHING RESULTS ===
# Ground Truth file: 110 matches found out of 111 rows
# Extracted Data file: 110 matches found out of 112 rows
# Ground Truth rows without matches: 1
# Extracted Data rows without matches: 2
#
# === UNMATCHED GROUND TRUTH ROWS ===
# GT No Match 1: Q2 from 08_1002109149818371111684649303
#
# === UNMATCHED EXTRACTED DATA ROWS ===
# Extracted No Match 1: Q3 from 08_1002109149818371111684649303
# Extracted No Match 2: Q12 from 13_10021000191039611111693742763
#
# === FINAL SUMMARY ===
# Ground Truth file had 110 matches out of 111 rows
# Extracted Data file had 2 rows which did not match
# Final CSV created: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/final_csv.csv
# Total rows in final CSV: 110

# %%
import pandas as pd
import re

def clean_text(text):
    """
    Clean text by removing <br>, <br/>, \n and converting to lowercase
    """
    if not text or text == "NA" or pd.isna(text):
        return text
    
    # Convert to string first (in case it's not)
    text = str(text)
    
    # Remove <br> and <br/> tags (case insensitive)
    text = re.sub(r'<br\s*/?>', '', text, flags=re.IGNORECASE)
    
    # Remove \n newline characters
    text = text.replace('\n', '')
    
    # Convert to lowercase
    text = text.lower()
    
    return text

def clean_bio_csv():
    """
    Clean the Bio final_csv.csv file by applying text cleaning to first two columns
    Updates the same file only if changes are needed
    """
    file_path = "/Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/final_csv.csv"
    
    print("🔧 Starting Bio CSV cleaning process...")
    print(f"📁 File to check: {file_path}")
    print("=" * 80)
    
    try:
        # Read the CSV file
        print("📖 Reading CSV file...")
        df = pd.read_csv(file_path)
        
        print(f"📊 Original file stats:")
        print(f"   • Total rows: {len(df)}")
        print(f"   • Columns: {list(df.columns)}")
        
        # Check if changes are needed
        print("\n🔍 Checking if cleaning is needed...")
        
        changes_needed = False
        claude_changes = 0
        ground_truth_changes = 0
        
        # Check Gemini_ocr column
        for idx, text in enumerate(df['Gemini_ocr']):
            if not pd.isna(text):
                original = str(text)
                cleaned = clean_text(text)
                if original != cleaned:
                    changes_needed = True
                    claude_changes += 1
        
        # Check Ground_Truth column
        for idx, text in enumerate(df['Ground_Truth']):
            if not pd.isna(text):
                original = str(text)
                cleaned = clean_text(text)
                if original != cleaned:
                    changes_needed = True
                    ground_truth_changes += 1
        
        print(f"📊 Changes needed analysis:")
        print(f"   • Gemini OCR rows needing changes: {claude_changes}")
        print(f"   • Ground Truth rows needing changes: {ground_truth_changes}")
        print(f"   • Total changes needed: {changes_needed}")
        
        if not changes_needed:
            print("\n✅ NO CHANGES NEEDED!")
            print("=" * 80)
            print("🎉 The file is already clean!")
            print("✓ No <br> or <br/> tags found")
            print("✓ No \\n newline characters found")
            print("✓ Text is already in lowercase")
            print("✓ File remains unchanged")
            print("=" * 80)
            return True, "No changes needed"
        
        # Show preview of cleaning for first changed row
        print("\n🔍 CLEANING PREVIEW:")
        print("-" * 80)
        
        # Find first row that needs cleaning for preview
        preview_shown = False
        for idx in range(len(df)):
            if not preview_shown:
                claude_original = df['Gemini_ocr'].iloc[idx] if not pd.isna(df['Gemini_ocr'].iloc[idx]) else ""
                ground_original = df['Ground_Truth'].iloc[idx] if not pd.isna(df['Ground_Truth'].iloc[idx]) else ""
                
                claude_cleaned = clean_text(claude_original)
                ground_cleaned = clean_text(ground_original)
                
                if claude_original != claude_cleaned or ground_original != ground_cleaned:
                    print(f"Gemini_ocr (Row {idx+1}):")
                    print(f"Before: {repr(str(claude_original)[:100])}...")
                    print(f"After:  {repr(claude_cleaned[:100])}...")
                    print()
                    print(f"GROUND_TRUTH (Row {idx+1}):")
                    print(f"Before: {repr(str(ground_original)[:100])}...")
                    print(f"After:  {repr(ground_cleaned[:100])}...")
                    print("-" * 80)
                    preview_shown = True
        
        # Apply cleaning to both columns
        print("\n🧹 Applying changes...")
        print("🧹 Cleaning Gemini_ocr column...")
        df['Gemini_ocr'] = df['Gemini_ocr'].apply(clean_text)
        
        print("🧹 Cleaning Ground_Truth column...")
        df['Ground_Truth'] = df['Ground_Truth'].apply(clean_text)
        
        # Save back to the same file
        print("💾 Updating the original CSV file...")
        df.to_csv(file_path, index=False, encoding='utf-8')
        
        print("\n✅ SUCCESS!")
        print("=" * 80)
        print(f"📊 CLEANING SUMMARY:")
        print("=" * 80)
        print(f"✓ Removed <br> and <br/> tags")
        print(f"✓ Removed \\n newline characters")
        print(f"✓ Converted text to lowercase")
        print(f"✓ Processed {len(df)} rows")
        print(f"✓ Gemini OCR changes: {claude_changes}")
        print(f"✓ Ground Truth changes: {ground_truth_changes}")
        print(f"✓ Original file updated: {file_path}")
        print("=" * 80)
        
        return True, file_path
        
    except Exception as e:
        print(f"❌ ERROR: {str(e)}")
        return False, str(e)

if __name__ == "__main__":
    print("🚀 Bio CSV Text Cleaning Tool")
    print("Will check if cleaning is needed for Gemini_ocr and Ground_Truth columns")
    print("Only updates file if changes are required")
    print("Removes: <br>, <br/>, \\n and converts to lowercase")
    print("=" * 80)
    
    success, result = clean_bio_csv()
    
    if success:
        if result == "No changes needed":
            print(f"\n🎉 Analysis completed - file is already clean!")
        else:
            print(f"\n🎉 Cleaning completed successfully!")
            print(f"📁 Original file has been updated: {result}")
    else:
        print(f"\n❌ Cleaning failed: {result}")
# Out:
# 🚀 Bio CSV Text Cleaning Tool
# Will check if cleaning is needed for Gemini_ocr and Ground_Truth columns
# Only updates file if changes are required
# Removes: <br>, <br/>, \n and converts to lowercase
# ================================================================================
# 🔧 Starting Bio CSV cleaning process...
# 📁 File to check: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/final_csv.csv
# ================================================================================
# 📖 Reading CSV file...
# 📊 Original file stats:
#    • Total rows: 110
#    • Columns: ['Ground_Truth', 'Gemini_ocr', 'Question_Number', 'pdf_source']
#
# 🔍 Checking if cleaning is needed...
# 📊 Changes needed analysis:
#    • Gemini OCR rows needing changes: 0
#    • Ground Truth rows needing changes: 30
#    • Total changes needed: True
#
# 🔍 CLEANING PREVIEW:
# --------------------------------------------------------------------------------
# Gemini_ocr (Row 9):
# Before: '9. the potential difference between the two ends of the conductor (v) = 10v - 5v = 5vpotential diffe'...
# After:  '9. the potential difference between the two ends of the conductor (v) = 10v - 5v = 5vpotential diffe'...
#
# GROUND_TRUTH (Row 9):
# Before: '9.The potential difference between the two ends of the conductor (V) = 10V - 5V = 5V\n∴potential diff'...
# After:  '9.the potential difference between the two ends of the conductor (v) = 10v - 5v = 5v∴potential diffe'...
# --------------------------------------------------------------------------------
#
# 🧹 Applying changes...
# 🧹 Cleaning Gemini_ocr column...
# 🧹 Cleaning Ground_Truth column...
# 💾 Updating the original CSV file...
#
# ✅ SUCCESS!
# ================================================================================
# 📊 CLEANING SUMMARY:
# ================================================================================
# ✓ Removed <br> and <br/> tags
# ✓ Removed \n newline characters
# ✓ Converted text to lowercase
# ✓ Processed 110 rows
# ✓ Gemini OCR changes: 0
# ✓ Ground Truth changes: 30
# ✓ Original file updated: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/final_csv.csv
# ================================================================================
#
# 🎉 Cleaning completed successfully!
# 📁 Original file has been updated: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/final_csv.csv

# %% [markdown]
# #to get pdf_wise csv

# %%
import pandas as pd
import os

def create_pdf_specific_csvs():
    """
    Create individual CSV files for each unique PDF source
    """
    # Define paths
    base_path = "/Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics"
    input_csv_path = os.path.join(base_path, "final_csv.csv")
    main_output_folder = os.path.join(base_path, "cer_pdf")
    
    print(f"📄 Reading CSV: {input_csv_path}")
    
    # Read the CSV file
    try:
        df = pd.read_csv(input_csv_path)
        print(f"✅ CSV loaded successfully with {len(df)} rows")
        print(f"📊 Columns: {list(df.columns)}")
    except Exception as e:
        print(f"❌ Error reading CSV: {e}")
        return
    
    # Get unique PDF sources from the 4th column (pdf_source)
    pdf_sources = df['pdf_source'].unique()
    print(f"\n🔍 Found {len(pdf_sources)} unique PDF sources:")
    for i, pdf_source in enumerate(pdf_sources, 1):
        print(f"   {i}. {pdf_source}")
    
    # Create main output directory
    os.makedirs(main_output_folder, exist_ok=True)
    print(f"\n📁 Created main directory: {main_output_folder}")
    
    # Process each unique PDF source
    for pdf_source in pdf_sources:
        # Remove .pdf extension for folder name
        pdf_name = pdf_source.replace('.pdf', '')
        
        # Create subfolder for this PDF source
        pdf_folder = os.path.join(main_output_folder, pdf_name)
        os.makedirs(pdf_folder, exist_ok=True)
        
        # Filter data for this PDF source
        pdf_data = df[df['pdf_source'] == pdf_source].copy()
        
        # Define output CSV path
        output_csv_path = os.path.join(pdf_folder, f"{pdf_name}.csv")
        
        # Save filtered data to CSV
        try:
            pdf_data.to_csv(output_csv_path, index=False)
            print(f"   ✅ Created: {output_csv_path}")
            print(f"      📊 Rows: {len(pdf_data)}")
        except Exception as e:
            print(f"   ❌ Error saving {pdf_name}: {e}")
    
    # Print summary
    print("\n" + "=" * 70)
    print("📊 PROCESSING SUMMARY")
    print("=" * 70)
    print(f"Total unique PDF sources: {len(pdf_sources)}")
    print(f"Main output directory: {main_output_folder}")
    print("\n📂 Directory structure created:")
    print(f"   {main_output_folder}/")
    for pdf_source in pdf_sources:
        pdf_name = pdf_source.replace('.pdf', '')
        print(f"   ├── {pdf_name}/")
        print(f"   │   └── {pdf_name}.csv")
    print("=" * 70)

def main():
    """
    Main function to execute the CSV splitting process
    """
    print("🔧 PDF-Specific CSV Creator")
    print("=" * 70)
    
    create_pdf_specific_csvs()
    
    print("\n✅ CSV splitting complete!")

if __name__ == "__main__":
    main()
# Out:
# 🔧 PDF-Specific CSV Creator
# ======================================================================
# 📄 Reading CSV: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/final_csv.csv
# ✅ CSV loaded successfully with 110 rows
# 📊 Columns: ['Ground_Truth', 'Gemini_ocr', 'Question_Number', 'pdf_source']
#
# 🔍 Found 15 unique PDF sources:
#    1. 01_10021040891039611111693747018
#    2. 02_1002137635994121111692517447
#    3. 03_10021054361083421111694958871
#    4. 04_100210408219741901111703509552
#    5. 05_1002110109818371111684651004
#    6. 06_100210285819741901111703513676
#    7. 07_100212788145098831111705212250
#    8. 08_1002109149818371111684649303
#    9. 09_1002114885961841111690700733
#    10. 10_10021138351083421111694954514
#    11. 11_100210067043036921111705241030
#    12. 12_1002140198994121111692513661
#    13. 13_10021000191039611111693742763
#    14. 14_1002108725961841111690697411
#    15. 15_10021105101083421111694960631
#
# 📁 Created main directory: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/cer_pdf
#    ✅ Created: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/cer_pdf/01_10021040891039611111693747018/01_10021040891039611111693747018.csv
#       📊 Rows: 11
#    ✅ Created: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/cer_pdf/02_1002137635994121111692517447/02_1002137635994121111692517447.csv
#       📊 Rows: 4
#    ✅ Created: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/cer_pdf/03_10021054361083421111694958871/03_10021054361083421111694958871.csv
#       📊 Rows: 12
#    ✅ Created: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/cer_pdf/04_100210408219741901111703509552/04_100210408219741901111703509552.csv
#       📊 Rows: 6
#    ✅ Created: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/cer_pdf/05_1002110109818371111684651004/05_1002110109818371111684651004.csv
#       📊 Rows: 4
#    ✅ Created: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/cer_pdf/06_100210285819741901111703513676/06_100210285819741901111703513676.csv
#       📊 Rows: 6
#    ✅ Created: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/cer_pdf/07_100212788145098831111705212250/07_100212788145098831111705212250.csv
#       📊 Rows: 12
#    ✅ Created: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/cer_pdf/08_1002109149818371111684649303/08_1002109149818371111684649303.csv
#       📊 Rows: 2
#    ✅ Created: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/cer_pdf/09_1002114885961841111690700733/09_1002114885961841111690700733.csv
#       📊 Rows: 4
#    ✅ Created: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/cer_pdf/10_10021138351083421111694954514/10_10021138351083421111694954514.csv
#       📊 Rows: 12
#    ✅ Created: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/cer_pdf/11_100210067043036921111705241030/11_100210067043036921111705241030.csv
#       📊 Rows: 6
#    ✅ Created: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/cer_pdf/12_1002140198994121111692513661/12_1002140198994121111692513661.csv
#       📊 Rows: 4
#    ✅ Created: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/cer_pdf/13_10021000191039611111693742763/13_10021000191039611111693742763.csv
#       📊 Rows: 11
#    ✅ Created: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/cer_pdf/14_1002108725961841111690697411/14_1002108725961841111690697411.csv
#       📊 Rows: 4
#    ✅ Created: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/cer_pdf/15_10021105101083421111694960631/15_10021105101083421111694960631.csv
#       📊 Rows: 12
#
# ======================================================================
# 📊 PROCESSING SUMMARY
# ======================================================================
# Total unique PDF sources: 15
# Main output directory: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/cer_pdf
#
# 📂 Directory structure created:
#    /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/cer_pdf/
#    ├── 01_10021040891039611111693747018/
#    │   └── 01_10021040891039611111693747018.csv
#    ├── 02_1002137635994121111692517447/
#    │   └── 02_1002137635994121111692517447.csv
#    ├── 03_10021054361083421111694958871/
#    │   └── 03_10021054361083421111694958871.csv
#    ├── 04_100210408219741901111703509552/
#    │   └── 04_100210408219741901111703509552.csv
#    ├── 05_1002110109818371111684651004/
#    │   └── 05_1002110109818371111684651004.csv
#    ├── 06_100210285819741901111703513676/
#    │   └── 06_100210285819741901111703513676.csv
#    ├── 07_100212788145098831111705212250/
#    │   └── 07_100212788145098831111705212250.csv
#    ├── 08_1002109149818371111684649303/
#    │   └── 08_1002109149818371111684649303.csv
#    ├── 09_1002114885961841111690700733/
#    │   └── 09_1002114885961841111690700733.csv
#    ├── 10_10021138351083421111694954514/
#    │   └── 10_10021138351083421111694954514.csv
#    ├── 11_100210067043036921111705241030/
#    │   └── 11_100210067043036921111705241030.csv
#    ├── 12_1002140198994121111692513661/
#    │   └── 12_1002140198994121111692513661.csv
#    ├── 13_10021000191039611111693742763/
#    │   └── 13_10021000191039611111693742763.csv
#    ├── 14_1002108725961841111690697411/
#    │   └── 14_1002108725961841111690697411.csv
#    ├── 15_10021105101083421111694960631/
#    │   └── 15_10021105101083421111694960631.csv
# ======================================================================
#
# ✅ CSV splitting complete!

# %% [markdown]
# ## to get cer

# %%
# !pip install python-Levenshtein
# !import pandas as pd
# Out:
# Requirement already satisfied: python-Levenshtein in /opt/anaconda3/envs/Layout_env/lib/python3.9/site-packages (0.27.1)
# Requirement already satisfied: Levenshtein==0.27.1 in /opt/anaconda3/envs/Layout_env/lib/python3.9/site-packages (from python-Levenshtein) (0.27.1)
# Requirement already satisfied: rapidfuzz<4.0.0,>=3.9.0 in /opt/anaconda3/envs/Layout_env/lib/python3.9/site-packages (from Levenshtein==0.27.1->python-Levenshtein) (3.10.1)
# zsh:1: command not found: import

# %%
import Levenshtein as lev
# 1. BASIC DISTANCE - Number of edits needed to transform one string to another
text1 = "hello world"
text2 = "hello word"
distance = lev.distance(text1, text2)
print(f"Edit distance: {distance}")
# Out:
# Edit distance: 1

# %%
import Levenshtein as lev

def normalize_levenshtien_distance(text1, text2):
    text1 = text1.replace(" ","").lower()
    text2 = text2.replace(" ","").lower()
    length_of_text1 = len(text1)
    length_of_text2 = len(text2)
    min_length = min(length_of_text1, length_of_text2)
    max_length = max(length_of_text1, length_of_text2)
    if length_of_text1 == 0 and length_of_text2 == 0:
        normalized_distance = 0
    elif min_length == 0:
        normalized_distance = 1
    else:
        distance = lev.distance(text1, text2)
        normalized_distance = distance / max_length
    return 1 - normalized_distance

# %%
df=pd.read_csv("/Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/cer_pdf/final_csv.csv")
df
# Out:
#                                           Ground_Truth  \
# 0                                     1. hypermetropia
# 1                                         2. repulsion
# 2                                 3. virtual and erect
# 3              4. below the apparent image of the fish
# 4    5. given: p = +1.5df = 1/pf = 1/1.5 mf = 2/3 m...
# ..                                                 ...
# 105  8.Given,\nObject distance, u = -10 cm, focal l...
# 106  9 given.u= -10cm, forms real image, m= -3v= ?,...
# 107  10. far point = x = 80 cm, f = p,⇒ formula for...
# 108  11. (a) convex lense(b) v/u or magnification w...
# 109  12. (a) Laws of Refraction of Light\n(i) The i...
#
#                                             Gemini_ocr  Question_Number  \
# 0                                     1. hypermetropia                1
# 1                                         2. repulsion                2
# 2                                 3. virtual and erect                3
# 3             4. below the apparent image of the fish.                4
# 4    5. given: p = +1.5df = 1/pf = 1/1.5 mf = 2/3 m...                5
# ..                                                 ...              ...
# 105  8. given, object distance u = -10cm, focal len...                8
# 106  9. given.u= -10cm, forms real image, m=-3v=?, ...                9
# 107  10. far point = x = 80cm, f=?=> formula for fo...               10
# 108  11. (a) convex lense(b) v/u or magnification w...               11
# 109  12. (a) laws of refraction of light(i) the inc...               12
#
#                            pdf_source
# 0    01_10021040891039611111693747018
# 1    01_10021040891039611111693747018
# 2    01_10021040891039611111693747018
# 3    01_10021040891039611111693747018
# 4    01_10021040891039611111693747018
# ..                                ...
# 105  15_10021105101083421111694960631
# 106  15_10021105101083421111694960631
# 107  15_10021105101083421111694960631
# 108  15_10021105101083421111694960631
# 109  15_10021105101083421111694960631
#
# [110 rows x 4 columns]

# %%
df['score']=df.apply(lambda x: normalize_levenshtien_distance(x['Ground_Truth'],x['Gemini_ocr']),axis=1)

# %%
df['length']=df.apply(lambda x: len(x['Ground_Truth']),axis=1)

# %%
(df.score*df.length).sum()/df.length.sum()
# Out:
# 0.884504116771829

# %%
df.length.sum()
# Out:
# 22995

# %%
df.score.hist(density = True)
# Out:
# <Axes: >

# %%
# Filter dataframe for scores not equal to 1 and sort by score in descending order
filtered_df = df[df['score'] != 1].sort_values(by='score', ascending=False)

# Reorder columns: ocr_text, corrected_ocr, score, length
columns_ordered = ['Gemini_ocr', 'Ground_Truth', 'score', 'length']
filtered_df_ordered = filtered_df[columns_ordered]

# Display all values
print("Filtered dataframe with scores != 1 (sorted by score descending):")
print("Columns: Gemini_ocr | Ground_Truth | score | length")
print(filtered_df_ordered)

# Save to CSV file with reordered columns
output_file = "/Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/cer_pdf/final_csv.csv"

filtered_df_ordered.to_csv(output_file, index=False)

print(f"\nResults saved to: {output_file}")
print(f"Number of rows with score != 1: {len(filtered_df_ordered)}")
print("CSV columns order: Gemini_ocr, Ground_Truth, score, length")
# Out:
# Filtered dataframe with scores != 1 (sorted by score descending):
# Columns: Gemini_ocr | Ground_Truth | score | length
#                                             Gemini_ocr  \
# 40   4. (i) principal focus of spherical mirror-whe...
# 21   7. (a) water is optically denser medium compar...
# 8    9. the potential difference between the two en...
# 103  a. 6. 2 common defects of vision:-(i) myopia >...
# 41   5. given (convex lens)(i) m = -1/5v = +18cmm =...
# ..                                                 ...
# 6    7. circuit components <diagram_1>symbol1) elec...
# 48   6 -> the ratio of speed of light in vacume and...
# 92   10) part i1) pole: it is a geometrical centre ...
# 93   11) part iithe range of distance is inbetween ...
# 89   7) circuit symbol of five important components...
#
#                                           Ground_Truth     score  length
# 40   4 (i) principal focus of spherical mirror-when...  0.996700     360
# 21   7. (a) water is optically denser medium compar...  0.995798     291
# 8    9.the potential difference between the two end...  0.993007     178
# 103  a. 6. 2 common defects of vision :-(i) myopia ...  0.989324     334
# 41   5. given (convex lens)(i) m = -1/5v = +18cmm =...  0.989130     222
# ..                                                 ...       ...     ...
# 6    7.| circuit components | symbol ||---|---|| 1)...  0.505000     240
# 48   6 -> the ratio of speed of light in vacume and...  0.461224     306
# 92   10) part i1) pole :- it is a geometrical centr...  0.417112     902
# 93   11) a) the sun appear reddish in the early mor...  0.259843     308
# 89   7) circuit symbol of five important components...  0.201550      65
#
# [72 rows x 4 columns]
#
# Results saved to: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/cer_pdf/final_csv.csv
# Number of rows with score != 1: 72
# CSV columns order: Gemini_ocr, Ground_Truth, score, length

# %%
df.sort_values(by='score',ascending=False)

# %%
import Levenshtein as lev
import pandas as pd
import os
from io import StringIO
import sys
import textwrap

def normalize_levenshtien_distance(text1, text2):
    text1 = text1.replace(" ","").lower()
    text2 = text2.replace(" ","").lower()
    length_of_text1 = len(text1)
    length_of_text2 = len(text2)
    min_length = min(length_of_text1, length_of_text2)
    max_length = max(length_of_text1, length_of_text2)
    if length_of_text1 == 0 and length_of_text2 == 0:
        normalized_distance = 0
    elif min_length == 0:
        normalized_distance = 1
    else:
        distance = lev.distance(text1, text2)
        normalized_distance = distance / max_length
    return 1 - normalized_distance

def wrap_text(text, width=50):
    """Wrap text to specified width"""
    if pd.isna(text) or text == "":
        return ""
    return '\n'.join(textwrap.wrap(str(text), width=width))

def print_wrapped_dataframe(df, title="Dataframe"):
    """Print dataframe with wrapped text for better readability"""
    print(f"\n{title}:")
    print("=" * 100)
    
    for idx, row in df.iterrows():
        print(f"\n--- Row {idx + 1} ---")
        print(f"Gemini_ocr:")
        print(textwrap.fill(str(row['Gemini_ocr']), width=80, initial_indent="  ", subsequent_indent="  "))
        print(f"\nGround_Truth:")
        print(textwrap.fill(str(row['Ground_Truth']), width=80, initial_indent="  ", subsequent_indent="  "))
        print(f"\nScore: {row['score']:.4f}")
        print(f"Length: {row['length']}")
        print("-" * 50)

def process_csv_file(csv_path, output_directory, file_identifier):
    """Process a single CSV file and generate results"""
    
    # Redirect stdout to capture print statements
    old_stdout = sys.stdout
    captured_output = StringIO()
    sys.stdout = captured_output
    
    try:
        # Load the input data
        df = pd.read_csv(csv_path)
        print(f"Processing: {csv_path}")
        print(f"Total number of rows in CSV: {len(df)}")
        
        # Calculate scores using the normalize_levenshtien_distance function
        df['score'] = df.apply(lambda x: normalize_levenshtien_distance(x['Ground_Truth'], x['Gemini_ocr']), axis=1)
        
        # Calculate length of Ground_Truth text
        df['length'] = df.apply(lambda x: len(x['Ground_Truth']), axis=1)
        
        # Save the complete dataframe with all rows and scores
        csv_base_name = os.path.splitext(os.path.basename(csv_path))[0]  # Get filename without extension
        complete_csv_file = os.path.join(output_directory, f"{csv_base_name}_final.csv")
        df.to_csv(complete_csv_file, index=False)
        print(f"Complete dataframe saved to: {complete_csv_file}")
        
        # Calculate weighted average score
        weighted_average_score = (df.score * df.length).sum() / df.length.sum()
        
        # Calculate total length sum
        total_length = df.length.sum()
        
        # Filter dataframe for scores not equal to 1 and sort by score in descending order
        filtered_df = df[df['score'] != 1].sort_values(by='score', ascending=False)
        
        # Reorder columns: ocr_text, corrected_ocr, score, length
        columns_ordered = ['Gemini_ocr', 'Ground_Truth', 'score', 'length']
        filtered_df_ordered = filtered_df[columns_ordered]
        
        # Display filtered results with text wrapping
        if len(filtered_df_ordered) > 0:
            print_wrapped_dataframe(filtered_df_ordered, "Filtered dataframe with scores != 1 (sorted by score descending)")
        else:
            print("\nNo rows found with scores != 1 (all perfect matches!)")
        
        # Save to CSV file with reordered columns
        output_csv_file = os.path.join(output_directory, "filtered_results.csv")
        filtered_df_ordered.to_csv(output_csv_file, index=False)
        
        print(f"\nFiltered results saved to: {output_csv_file}")
        print(f"Total number of rows in original CSV: {len(df)}")
        print(f"Number of rows with score != 1: {len(filtered_df_ordered)}")
        print(f"Number of rows with score = 1: {len(df) - len(filtered_df_ordered)}")
        print("CSV columns order: Gemini_ocr, Ground_Truth, score, length")
        print(f"Weighted average score: {weighted_average_score:.4f}")
        print(f"Total length: {total_length}")
        
        # Restore stdout
        sys.stdout = old_stdout
        output_text = captured_output.getvalue()
        
        # Save output to text file
        output_txt_file = os.path.join(output_directory, "output.txt")
        with open(output_txt_file, 'w', encoding='utf-8') as f:
            f.write(output_text)
        
        print(f"✅ Successfully processed {file_identifier}")
        print(f"   - Total rows: {len(df)}")
        print(f"   - Complete CSV: {complete_csv_file}")
        print(f"   - Filtered CSV: {output_csv_file}")
        print(f"   - Text output: {output_txt_file}")
        
        # Return summary statistics for the final table
        return {
            'csv_name': csv_base_name,
            'average_score': weighted_average_score,
            'total_length': total_length,
            'total_rows': len(df),
            'rows_with_score_not_1': len(filtered_df_ordered)
        }
        
    except Exception as e:
        sys.stdout = old_stdout
        print(f"❌ Error processing {file_identifier}: {str(e)}")
        return None

def create_summary_table(summary_data, base_directory):
    """Create final summary table with all statistics"""
    
    if not summary_data:
        print("❌ No data to create summary table")
        return
    
    # Create DataFrame from summary data
    summary_df = pd.DataFrame(summary_data)
    
    # Reorder columns as requested
    summary_df = summary_df[['csv_name', 'average_score', 'total_length', 'total_rows', 'rows_with_score_not_1']]
    
    # Rename columns for better readability
    summary_df.columns = ['CSV_Name', 'Average_Score', 'Total_Length', 'Total_Rows', 'Rows_Score_Not_1']
    
    # Round average score to 4 decimal places
    summary_df['Average_Score'] = summary_df['Average_Score'].round(4)
    
    # Save as CSV
    output_csv_path = os.path.join(base_directory, "output_table.csv")
    summary_df.to_csv(output_csv_path, index=False)
    
    # Create formatted text table
    output_txt_path = os.path.join(base_directory, "final_table.txt")
    
    with open(output_txt_path, 'w', encoding='utf-8') as f:
        f.write("FINAL SUMMARY TABLE\n")
        f.write("=" * 100 + "\n\n")
        
        # Write column headers
        f.write(f"{'CSV Name':<30} {'Avg Score':<12} {'Total Length':<15} {'Total Rows':<12} {'Rows Score != 1':<15}\n")
        f.write("-" * 100 + "\n")
        
        # Write data rows
        for _, row in summary_df.iterrows():
            f.write(f"{row['CSV_Name']:<30} {row['Average_Score']:<12.4f} {row['Total_Length']:<15} {row['Total_Rows']:<12} {row['Rows_Score_Not_1']:<15}\n")
        
        f.write("\n" + "=" * 100 + "\n")
        f.write(f"TOTALS:\n")
        f.write(f"Total CSVs processed: {len(summary_df)}\n")
        f.write(f"Overall total rows: {summary_df['Total_Rows'].sum()}\n")
        f.write(f"Overall total length: {summary_df['Total_Length'].sum()}\n")
        f.write(f"Overall rows with score != 1: {summary_df['Rows_Score_Not_1'].sum()}\n")
        f.write(f"Overall weighted average score: {(summary_df['Average_Score'] * summary_df['Total_Length']).sum() / summary_df['Total_Length'].sum():.4f}\n")
    
    print(f"\n📊 Summary Table Created:")
    print(f"   - CSV file: {output_csv_path}")
    print(f"   - Text file: {output_txt_path}")
    print(f"\nSummary Table Contents:")
    print(summary_df.to_string(index=False))

def main():
    """Main function to process all subdirectories and final_csv.csv"""
    base_directory = "/Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/cer_pdf"
    
    if not os.path.exists(base_directory):
        print(f"❌ Base directory not found: {base_directory}")
        return
    
    print(f"🔍 Processing directory: {base_directory}")
    print("=" * 70)
    
    processed_count = 0
    success_count = 0
    summary_data = []
    
    # First, check for final_csv.csv in the main directory
    final_csv_path = os.path.join(base_directory, "final_csv.csv")
    if os.path.exists(final_csv_path):
        print(f"\n🔄 Processing main file: final_csv.csv")
        processed_count += 1
        result = process_csv_file(final_csv_path, base_directory, "final_csv.csv")
        if result:
            success_count += 1
            summary_data.append(result)
    else:
        print(f"⚠️  final_csv.csv not found in main directory")
    
    # Then process all subdirectories
    for item in os.listdir(base_directory):
        subdirectory_path = os.path.join(base_directory, item)
        
        # Skip if not a directory
        if not os.path.isdir(subdirectory_path):
            continue
        
        # Look for CSV file with same name as subdirectory
        csv_filename = f"{item}.csv"
        csv_path = os.path.join(subdirectory_path, csv_filename)
        
        print(f"\n🔄 Processing subdirectory: {item}")
        
        if os.path.exists(csv_path):
            processed_count += 1
            result = process_csv_file(csv_path, subdirectory_path, item)
            if result:
                success_count += 1
                summary_data.append(result)
        else:
            print(f"⚠️  CSV file not found: {csv_path}")
    
    print("\n" + "=" * 70)
    print(f"📊 Processing Summary:")
    print(f"   Total files processed: {processed_count}")
    print(f"   Successfully processed: {success_count}")
    print(f"   Failed: {processed_count - success_count}")
    
    # Create summary table
    if summary_data:
        create_summary_table(summary_data, base_directory)
    else:
        print("❌ No successful processing results to create summary table")

if __name__ == "__main__":
    main()
# Out:
# 🔍 Processing directory: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/cer_pdf
# ======================================================================
#
# 🔄 Processing main file: final_csv.csv
# ✅ Successfully processed final_csv.csv
#    - Total rows: 110
#    - Complete CSV: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/cer_pdf/final_csv_final.csv
#    - Filtered CSV: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/cer_pdf/filtered_results.csv
#    - Text output: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/cer_pdf/output.txt
#
# 🔄 Processing subdirectory: 12_1002140198994121111692513661
# ✅ Successfully processed 12_1002140198994121111692513661
#    - Total rows: 4
#    - Complete CSV: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/cer_pdf/12_1002140198994121111692513661/12_1002140198994121111692513661_final.csv
#    - Filtered CSV: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/cer_pdf/12_1002140198994121111692513661/filtered_results.csv
#    - Text output: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/cer_pdf/12_1002140198994121111692513661/output.txt
#
# 🔄 Processing subdirectory: 09_1002114885961841111690700733
# ✅ Successfully processed 09_1002114885961841111690700733
#    - Total rows: 4
#    - Complete CSV: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/cer_pdf/09_1002114885961841111690700733/09_1002114885961841111690700733_final.csv
#    - Filtered CSV: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/cer_pdf/09_1002114885961841111690700733/filtered_results.csv
#    - Text output: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/cer_pdf/09_1002114885961841111690700733/output.txt
#
# 🔄 Processing subdirectory: 10_10021138351083421111694954514
# ✅ Successfully processed 10_10021138351083421111694954514
#    - Total rows: 12
#    - Complete CSV: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/cer_pdf/10_10021138351083421111694954514/10_10021138351083421111694954514_final.csv
#    - Filtered CSV: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/cer_pdf/10_10021138351083421111694954514/filtered_results.csv
#    - Text output: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/cer_pdf/10_10021138351083421111694954514/output.txt
#
# 🔄 Processing subdirectory: 02_1002137635994121111692517447
# ✅ Successfully processed 02_1002137635994121111692517447
#    - Total rows: 4
#    - Complete CSV: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/cer_pdf/02_1002137635994121111692517447/02_1002137635994121111692517447_final.csv
#    - Filtered CSV: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/cer_pdf/02_1002137635994121111692517447/filtered_results.csv
#    - Text output: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/cer_pdf/02_1002137635994121111692517447/output.txt
#
# 🔄 Processing subdirectory: 13_10021000191039611111693742763
# ✅ Successfully processed 13_10021000191039611111693742763
#    - Total rows: 11
#    - Complete CSV: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/cer_pdf/13_10021000191039611111693742763/13_10021000191039611111693742763_final.csv
#    - Filtered CSV: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/cer_pdf/13_10021000191039611111693742763/filtered_results.csv
#    - Text output: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/cer_pdf/13_10021000191039611111693742763/output.txt
#
# 🔄 Processing subdirectory: 11_100210067043036921111705241030
# ✅ Successfully processed 11_100210067043036921111705241030
#    - Total rows: 6
#    - Complete CSV: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/cer_pdf/11_100210067043036921111705241030/11_100210067043036921111705241030_final.csv
#    - Filtered CSV: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/cer_pdf/11_100210067043036921111705241030/filtered_results.csv
#    - Text output: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/cer_pdf/11_100210067043036921111705241030/output.txt
#
# 🔄 Processing subdirectory: 01_10021040891039611111693747018
# ✅ Successfully processed 01_10021040891039611111693747018
#    - Total rows: 11
#    - Complete CSV: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/cer_pdf/01_10021040891039611111693747018/01_10021040891039611111693747018_final.csv
#    - Filtered CSV: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/cer_pdf/01_10021040891039611111693747018/filtered_results.csv
#    - Text output: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/cer_pdf/01_10021040891039611111693747018/output.txt
#
# 🔄 Processing subdirectory: 08_1002109149818371111684649303
# ✅ Successfully processed 08_1002109149818371111684649303
#    - Total rows: 2
#    - Complete CSV: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/cer_pdf/08_1002109149818371111684649303/08_1002109149818371111684649303_final.csv
#    - Filtered CSV: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/cer_pdf/08_1002109149818371111684649303/filtered_results.csv
#    - Text output: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/cer_pdf/08_1002109149818371111684649303/output.txt
#
# 🔄 Processing subdirectory: 05_1002110109818371111684651004
# ✅ Successfully processed 05_1002110109818371111684651004
#    - Total rows: 4
#    - Complete CSV: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/cer_pdf/05_1002110109818371111684651004/05_1002110109818371111684651004_final.csv
#    - Filtered CSV: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/cer_pdf/05_1002110109818371111684651004/filtered_results.csv
#    - Text output: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/cer_pdf/05_1002110109818371111684651004/output.txt
#
# 🔄 Processing subdirectory: 04_100210408219741901111703509552
# ✅ Successfully processed 04_100210408219741901111703509552
#    - Total rows: 6
#    - Complete CSV: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/cer_pdf/04_100210408219741901111703509552/04_100210408219741901111703509552_final.csv
#    - Filtered CSV: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/cer_pdf/04_100210408219741901111703509552/filtered_results.csv
#    - Text output: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/cer_pdf/04_100210408219741901111703509552/output.txt
#
# 🔄 Processing subdirectory: 03_10021054361083421111694958871
# ✅ Successfully processed 03_10021054361083421111694958871
#    - Total rows: 12
#    - Complete CSV: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/cer_pdf/03_10021054361083421111694958871/03_10021054361083421111694958871_final.csv
#    - Filtered CSV: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/cer_pdf/03_10021054361083421111694958871/filtered_results.csv
#    - Text output: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/cer_pdf/03_10021054361083421111694958871/output.txt
#
# 🔄 Processing subdirectory: 14_1002108725961841111690697411
# ✅ Successfully processed 14_1002108725961841111690697411
#    - Total rows: 4
#    - Complete CSV: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/cer_pdf/14_1002108725961841111690697411/14_1002108725961841111690697411_final.csv
#    - Filtered CSV: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/cer_pdf/14_1002108725961841111690697411/filtered_results.csv
#    - Text output: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/cer_pdf/14_1002108725961841111690697411/output.txt
#
# 🔄 Processing subdirectory: 06_100210285819741901111703513676
# ✅ Successfully processed 06_100210285819741901111703513676
#    - Total rows: 6
#    - Complete CSV: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/cer_pdf/06_100210285819741901111703513676/06_100210285819741901111703513676_final.csv
#    - Filtered CSV: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/cer_pdf/06_100210285819741901111703513676/filtered_results.csv
#    - Text output: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/cer_pdf/06_100210285819741901111703513676/output.txt
#
# 🔄 Processing subdirectory: 07_100212788145098831111705212250
# ✅ Successfully processed 07_100212788145098831111705212250
#    - Total rows: 12
#    - Complete CSV: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/cer_pdf/07_100212788145098831111705212250/07_100212788145098831111705212250_final.csv
#    - Filtered CSV: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/cer_pdf/07_100212788145098831111705212250/filtered_results.csv
#    - Text output: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/cer_pdf/07_100212788145098831111705212250/output.txt
#
# 🔄 Processing subdirectory: 15_10021105101083421111694960631
# ✅ Successfully processed 15_10021105101083421111694960631
#    - Total rows: 12
#    - Complete CSV: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/cer_pdf/15_10021105101083421111694960631/15_10021105101083421111694960631_final.csv
#    - Filtered CSV: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/cer_pdf/15_10021105101083421111694960631/filtered_results.csv
#    - Text output: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/cer_pdf/15_10021105101083421111694960631/output.txt
#
# ======================================================================
# 📊 Processing Summary:
#    Total files processed: 16
#    Successfully processed: 16
#    Failed: 0
#
# 📊 Summary Table Created:
#    - CSV file: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/cer_pdf/output_table.csv
#    - Text file: /Users/simrannaik/Desktop/solution_improvement/ds-prototypes/subjective_grading/solution_improvement/z3_ocr_gemini_pcmb/Physics/cer_pdf/final_table.txt
#
# Summary Table Contents:
#                          CSV_Name  Average_Score  Total_Length  Total_Rows  Rows_Score_Not_1
#                         final_csv         0.8845         23335         110                73
#   12_1002140198994121111692513661         0.9332           766           4                 3
#   09_1002114885961841111690700733         0.9171           777           4                 1
#  10_10021138351083421111694954514         0.9483          2286          12                12
#   02_1002137635994121111692517447         0.8610           511           4                 4
#  13_10021000191039611111693742763         0.5656          2216          11                 7
# 11_100210067043036921111705241030         0.9010          1891           6                 6
#  01_10021040891039611111693747018         0.9261          2764          11                 6
#   08_1002109149818371111684649303         0.8286           340           2                 2
#   05_1002110109818371111684651004         0.9724           544           4                 2
# 04_100210408219741901111703509552         0.9650          1566           6                 2
#  03_10021054361083421111694958871         0.9539          2021          12                 6
#   14_1002108725961841111690697411         0.9472           512           4                 3
# 06_100210285819741901111703513676         0.9499          1654           6                 4
# 07_100212788145098831111705212250         0.8256          2532          12                 7
#  15_10021105101083421111694960631         0.9110          2955          12                 8
